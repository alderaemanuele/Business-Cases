# %% [markdown]
# # Business Case 3 - Recommender System

# %% [markdown]
# - Emanuele Aldera, m20210617
# - Robin Schmidt, m20210602
# - Muhammad Abdullah, m20210655
# - Rui Ramos, m20210640

# %% [markdown]
# ## Importing Libraries and Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
from math import ceil 
from datetime import datetime
# %pip install abc_analysis
from abc_analysis import abc_analysis
from mlxtend.frequent_patterns import apriori, association_rules
from tabulate import tabulate

from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score

import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("retail.csv")
data_orig = data.copy()
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...                 ...        ...         ...             ...
# 541904  12/9/2011 12:50       0.85     12680.0          France
# 541905  12/9/2011 12:50       2.10     12680.0          France
# 541906  12/9/2011 12:50       4.15     12680.0          France
# 541907  12/9/2011 12:50       4.15     12680.0          France
# 541908  12/9/2011 12:50       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
data["InvoiceDate"] = pd.to_datetime(data["InvoiceDate"])
data["Year"] = data["InvoiceDate"].dt.year
data["Month"] = data["InvoiceDate"].dt.month
# data["MonthName"] = data["InvoiceDate"].dt.month_name()
data["Day"] = data["InvoiceDate"].dt.day
data["Weekday"] = data["InvoiceDate"].dt.weekday +1
data["WeekdayName"] = data["InvoiceDate"].dt.day_name()
data["IsWeekend"] = data["Weekday"] > 5
data["Time"] = data["InvoiceDate"].dt.time
data["Hour"] = data["InvoiceDate"].dt.hour
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 16 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
#  8   Year         541909 non-null  int64
#  9   Month        541909 non-null  int64
#  10  Day          541909 non-null  int64
#  11  Weekday      541909 non-null  int64
#  12  WeekdayName  541909 non-null  object
#  13  IsWeekend    541909 non-null  bool
#  14  Time         541909 non-null  object
#  15  Hour         541909 non-null  int64
# dtypes: bool(1), datetime64[ns](1), float64(2), int64(6), object(6)
# memory usage: 62.5+ MB

# %%
def f(x):
    if (x > 4) and (x <= 8):
        return 'Early Morning'
    elif (x > 8) and (x <= 12 ):
        return 'Morning'
    elif (x > 12) and (x <= 16):
        return'Noon'
    elif (x > 16) and (x <= 20) :
        return 'Eve'
    elif (x > 20) and (x <= 24):
        return'Night'
    elif (x <= 4):
        return'Late Night'

prods = pd.DataFrame({'hour':range(1, 25)})

b = [0,4,8,12,16,20,24]
l = ['Late Night', 'Early Morning','Morning','Noon','Eve','Night']
prods['session'] = pd.cut(prods['hour'], bins=b, labels=l, include_lowest=True)

data["DayTime"] = data['Hour'].apply(f)

# %%
prods = pd.DataFrame({'hour':range(1, 25)})

b = [0,4,8,12,16,20,24]
l = ['Late Night', 'Early Morning','Morning','Noon','Eve','Night']
prods['session'] = pd.cut(prods['hour'], bins=b, labels=l, include_lowest=True)

# %%
data.describe().T
# Out:
#                count          mean          std       min       25%       50%  \
# Quantity    541909.0      9.552250   218.081158 -80995.00      1.00      3.00
# UnitPrice   541909.0      4.611114    96.759853 -11062.06      1.25      2.08
# CustomerID  406829.0  15287.690570  1713.600303  12346.00  13953.00  15152.00
# Year        541909.0   2010.921609     0.268787   2010.00   2011.00   2011.00
# Month       541909.0      7.553128     3.509055      1.00      5.00      8.00
# Day         541909.0     15.023096     8.664063      1.00      7.00     15.00
# Weekday     541909.0      3.431277     1.844709      1.00      2.00      3.00
# Hour        541909.0     13.078729     2.443270      6.00     11.00     13.00
#
#                  75%      max
# Quantity       10.00  80995.0
# UnitPrice       4.13  38970.0
# CustomerID  16791.00  18287.0
# Year         2011.00   2011.0
# Month          11.00     12.0
# Day            22.00     31.0
# Weekday         5.00      7.0
# Hour           15.00     20.0

# %% [markdown]
# ## Data exploration

# %% [markdown]
# Business understanding

# %%
#Counting the important features to have the notion of the dimension
print('The number of countries is:', data.Country.nunique())
print('The number of customers with observations is:', data.CustomerID.nunique())
print('The number of Products with transactions is:', data.Description.nunique())
# Out:
# The number of countries is: 38
# The number of customers with observations is: 4372
# The number of Products with transactions is: 4223

# %%
table1 = [['N. Countries', 'N. customers', 'N. Products'],[data.Country.nunique(), data.CustomerID.nunique(), data.Description.nunique()]]
print(tabulate(table1, headers='firstrow', tablefmt='fancy_grid'))
# Out:
# ╒════════════════╤════════════════╤═══════════════╕
# │   N. Countries │   N. customers │   N. Products │
# ╞════════════════╪════════════════╪═══════════════╡
# │             38 │           4372 │          4223 │
# ╘════════════════╧════════════════╧═══════════════╛

# %%
data.head(1)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Year  Month  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom  2010     12
#
#    Day  Weekday WeekdayName  IsWeekend      Time  Hour        DayTime
# 0    1        3   Wednesday      False  08:26:00     8  Early Morning

# %%
data["Sales"]= data["UnitPrice"] * data["Quantity"]

# %%
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Year  Month  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom  2010     12
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  2010     12
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom  2010     12
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  2010     12
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  2010     12
#
#    Day  Weekday WeekdayName  IsWeekend      Time  Hour        DayTime  Sales
# 0    1        3   Wednesday      False  08:26:00     8  Early Morning  15.30
# 1    1        3   Wednesday      False  08:26:00     8  Early Morning  20.34
# 2    1        3   Wednesday      False  08:26:00     8  Early Morning  22.00
# 3    1        3   Wednesday      False  08:26:00     8  Early Morning  20.34
# 4    1        3   Wednesday      False  08:26:00     8  Early Morning  20.34

# %%
data.Year.unique()
# Out:
# array([2010, 2011], dtype=int64)

# %%
def boxplot (data):
    from math import ceil

    metric_features = data.select_dtypes(include=np.number).set_index(data.index).columns
    sns.set()
    
    fig, axes = plt.subplots(2, ceil(len(metric_features) / 2), figsize=(20, 11))

    
    for ax, feat in zip(axes.flatten(), metric_features): 

        sns.boxplot(x = data[feat], ax = ax)
        

    
    title = "Numeric Variables' Boxplots"

    plt.suptitle(title)

    plt.show()

# %%
sales_his=data.groupby(['Country','Year'],sort=True).mean()[['Sales']].unstack().plot(kind="bar",width = 1)

# %%
popular_sales = pd.DataFrame(data.groupby('Country')['Sales'].sum())
most_popular = popular_sales.sort_values('Sales', ascending=False)
most_popular.head(15)
# Out:
#                        Sales
# Country
# United Kingdom   8187806.364
# Netherlands       284661.540
# EIRE              263276.820
# Germany           221698.210
# France            197403.900
# Australia         137077.270
# Switzerland        56385.350
# Spain              54774.580
# Belgium            40910.960
# Sweden             36595.910
# Japan              35340.620
# Norway             35163.460
# Portugal           29367.020
# Finland            22326.740
# Channel Islands    20086.290

# %%
most_popular.head(15).plot(kind = "bar")
# Out:
# <AxesSubplot:xlabel='Country'>

# %%
def boxplot (data):
    from math import ceil

    metric_features = data.select_dtypes(include=np.number).set_index(data.index).columns
    sns.set()
    
    fig, axes = plt.subplots(2, ceil(len(metric_features) / 2), figsize=(20, 11))

    
    for ax, feat in zip(axes.flatten(), metric_features): 

        sns.boxplot(x = data[feat], ax = ax)
        

    
    title = "Numeric Variables' Boxplots"

    plt.suptitle(title)

    plt.show()

# %%
numeric_features = data.select_dtypes(include=np.number).set_index(data.index).columns.tolist()
boxplot(data[numeric_features])

# %%
#removing "outliers"
data = data[data["Quantity"]<10000]
data = data[data["UnitPrice"]<600]

# %% [markdown]
# Cancelations

# %%
cancelations = data.loc[data["InvoiceNo"].str.contains("C")]
cancelations
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Year  \
# 141    2010-12-01 09:41:00      27.50     14527.0  United Kingdom  2010
# 154    2010-12-01 09:49:00       4.65     15311.0  United Kingdom  2010
# 235    2010-12-01 10:24:00       1.65     17548.0  United Kingdom  2010
# 236    2010-12-01 10:24:00       0.29     17548.0  United Kingdom  2010
# 237    2010-12-01 10:24:00       0.29     17548.0  United Kingdom  2010
# ...                    ...        ...         ...             ...   ...
# 540449 2011-12-09 09:57:00       0.83     14397.0  United Kingdom  2011
# 541541 2011-12-09 10:28:00     224.69     15498.0  United Kingdom  2011
# 541715 2011-12-09 11:57:00      10.95     15311.0  United Kingdom  2011
# 541716 2011-12-09 11:58:00       1.25     17315.0  United Kingdom  2011
# 541717 2011-12-09 11:58:00       1.25     17315.0  United Kingdom  2011
#
#         Month  Day  Weekday WeekdayName  IsWeekend      Time  Hour  DayTime  \
# 141        12    1        3   Wednesday      False  09:41:00     9  Morning
# 154        12    1        3   Wednesday      False  09:49:00     9  Morning
# 235        12    1        3   Wednesday      False  10:24:00    10  Morning
# 236        12    1        3   Wednesday      False  10:24:00    10  Morning
# 237        12    1        3   Wednesday      False  10:24:00    10  Morning
# ...       ...  ...      ...         ...        ...       ...   ...      ...
# 540449     12    9        5      Friday      False  09:57:00     9  Morning
# 541541     12    9        5      Friday      False  10:28:00    10  Morning
# 541715     12    9        5      Friday      False  11:57:00    11  Morning
# 541716     12    9        5      Friday      False  11:58:00    11  Morning
# 541717     12    9        5      Friday      False  11:58:00    11  Morning
#
#          Sales
# 141     -27.50
# 154      -4.65
# 235     -19.80
# 236      -6.96
# 237      -6.96
# ...        ...
# 540449   -9.13
# 541541 -224.69
# 541715  -54.75
# 541716   -1.25
# 541717   -6.25
#
# [9200 rows x 18 columns]

# %%
len(cancelations["InvoiceNo"].unique())
# Out:
# 3754

# %%
#check consistency for cancelations, we shouldnt have any cancelations with quantity > 0
cancelations.loc[cancelations["Quantity"] > 0]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country, Year, Month, Day, Weekday, WeekdayName, IsWeekend, Time, Hour, DayTime, Sales]
# Index: []

# %%
#check if for cancellations we have also the non cancelled record
cancelations2 = cancelations.copy()

#deleting C into cancelled invoices to have a joinable column to original df
cancelations2["InvoiceNo"] = cancelations2["InvoiceNo"].str.replace("C", "")

#results finds 0 records --> no duplicated records
pd.merge(left = data, right = cancelations2, how = "inner", on = "InvoiceNo")
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode_x, Description_x, Quantity_x, InvoiceDate_x, UnitPrice_x, CustomerID_x, Country_x, Year_x, Month_x, Day_x, Weekday_x, WeekdayName_x, IsWeekend_x, Time_x, Hour_x, DayTime_x, Sales_x, StockCode_y, Description_y, Quantity_y, InvoiceDate_y, UnitPrice_y, CustomerID_y, Country_y, Year_y, Month_y, Day_y, Weekday_y, WeekdayName_y, IsWeekend_y, Time_y, Hour_y, DayTime_y, Sales_y]
# Index: []
#
# [0 rows x 35 columns]

# %%
#removing from dataset cancelations
data = data[data["Quantity"] >= 0]

# %% [markdown]
# Missing values

# %%
data.isna().sum(axis = 0)
# Out:
# InvoiceNo           0
# StockCode           0
# Description       592
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     133274
# Country             0
# Year                0
# Month               0
# Day                 0
# Weekday             0
# WeekdayName         0
# IsWeekend           0
# Time                0
# Hour                0
# DayTime             0
# Sales               0
# dtype: int64

# %%
#showing records not having customer id
data[data.CustomerID.isna()]
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 622       536414     22139                              NaN        56
# 1443      536544     21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444      536544     21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445      536544     21786               POLKADOT RAIN HAT          4
# 1446      536544     21787            RAIN PONCHO RETROSPOT         2
# ...          ...       ...                              ...       ...
# 541535    581498    85049e        SCANDINAVIAN REDS RIBBONS         4
# 541536    581498    85099B          JUMBO BAG RED RETROSPOT         5
# 541537    581498    85099C   JUMBO  BAG BAROQUE BLACK WHITE         4
# 541538    581498     85150    LADIES & GENTLEMEN METAL SIGN         1
# 541539    581498     85174                S/4 CACTI CANDLES         1
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Year  \
# 622    2010-12-01 11:52:00       0.00         NaN  United Kingdom  2010
# 1443   2010-12-01 14:32:00       2.51         NaN  United Kingdom  2010
# 1444   2010-12-01 14:32:00       2.51         NaN  United Kingdom  2010
# 1445   2010-12-01 14:32:00       0.85         NaN  United Kingdom  2010
# 1446   2010-12-01 14:32:00       1.66         NaN  United Kingdom  2010
# ...                    ...        ...         ...             ...   ...
# 541535 2011-12-09 10:26:00       3.29         NaN  United Kingdom  2011
# 541536 2011-12-09 10:26:00       4.13         NaN  United Kingdom  2011
# 541537 2011-12-09 10:26:00       4.13         NaN  United Kingdom  2011
# 541538 2011-12-09 10:26:00       4.96         NaN  United Kingdom  2011
# 541539 2011-12-09 10:26:00      10.79         NaN  United Kingdom  2011
#
#         Month  Day  Weekday WeekdayName  IsWeekend      Time  Hour  DayTime  \
# 622        12    1        3   Wednesday      False  11:52:00    11  Morning
# 1443       12    1        3   Wednesday      False  14:32:00    14     Noon
# 1444       12    1        3   Wednesday      False  14:32:00    14     Noon
# 1445       12    1        3   Wednesday      False  14:32:00    14     Noon
# 1446       12    1        3   Wednesday      False  14:32:00    14     Noon
# ...       ...  ...      ...         ...        ...       ...   ...      ...
# 541535     12    9        5      Friday      False  10:26:00    10  Morning
# 541536     12    9        5      Friday      False  10:26:00    10  Morning
# 541537     12    9        5      Friday      False  10:26:00    10  Morning
# 541538     12    9        5      Friday      False  10:26:00    10  Morning
# 541539     12    9        5      Friday      False  10:26:00    10  Morning
#
#         Sales
# 622      0.00
# 1443     2.51
# 1444     5.02
# 1445     3.40
# 1446     3.32
# ...       ...
# 541535  13.16
# 541536  20.65
# 541537  16.52
# 541538   4.96
# 541539  10.79
#
# [133274 rows x 18 columns]

# %%
# number of invoices not having at least one missing customer id value
len(data[data.CustomerID.isna()]["InvoiceNo"].unique())
# Out:
# 2182

# %% [markdown]
# Data Consistency

# %%
#checking dataset consistency - for each invoice only one customer id associated
grouped = data.groupby("InvoiceNo")["CustomerID"].nunique(dropna=False)
grouped.sort_values(ascending = False)
# Out:
# InvoiceNo
# 536365     1
# 566874     1
# 566829     1
# 566823     1
# 566822     1
#           ..
# 551944     1
# 551907     1
# 551902     1
# 551900     1
# A563187    1
# Name: CustomerID, Length: 20695, dtype: int64

# %%
#checking dataset consistency - for each stock code only one description associated
grouped = data.groupby("StockCode")["Description"].nunique(dropna=False)
grouped.sort_values(ascending = False)
# Out:
# StockCode
# 23084     7
# 20713     7
# 22734     5
# 21181     5
# 85135B    4
#          ..
# 22526     1
# 22528     1
# 22529     1
# 22530     1
# m         1
# Name: Description, Length: 3940, dtype: int64

# %%
# by looking at results we decide not to take care of this issue, we just use stock code
data[data["StockCode"] == "20713"]["Description"].unique()
# Out:
# array(['JUMBO BAG OWLS', nan, 'found', 'Found', 'wrongly marked 23343',
#        'Marked as 23343', 'wrongly coded 23343'], dtype=object)

# %% [markdown]
# Taking care of stock codes not associated to products

# %%
print("Value counts of StockCodes with string lenght minor than 5")
print(data[data["StockCode"].str.len()<5].value_counts("StockCode"))
print()
print("Description associated")
print(data[data["StockCode"].str.len()<5].value_counts("Description"))
# Out:
# Value counts of StockCodes with string lenght minor than 5
# StockCode
# POST    1128
# DOT      625
# M        296
# C2       142
# PADS       4
# B          2
# S          2
# m          1
# dtype: int64
#
# Description associated
# Description
# POSTAGE                       1124
# DOTCOM POSTAGE                 624
# Manual                         297
# CARRIAGE                       141
# PADS TO MATCH ALL CUSHIONS       4
# Adjust bad debt                  2
# SAMPLES                          2
# dtype: int64

# %%
# deleting stock codes with len < 5 ()
del_stockcodes = data[data["StockCode"].str.len()<5].StockCode.unique().tolist()
data = data[~data["StockCode"].isin(del_stockcodes)]

# %% [markdown]
# Items with price associated 0

# %%
# quick look on invoices having cost 0
data[data.UnitPrice == 0]
# Out:
#        InvoiceNo StockCode                   Description  Quantity  \
# 622       536414     22139                           NaN        56
# 1970      536545     21134                           NaN         1
# 1971      536546     22145                           NaN         1
# 1972      536547     37509                           NaN         1
# 1987      536549    85226A                           NaN         1
# ...          ...       ...                           ...       ...
# 535334    581211     22142                         check        14
# 536981    581234     72817                           NaN        27
# 538504    581406    46000M  POLYESTER FILLER PAD 45x45cm       240
# 538505    581406    46000S  POLYESTER FILLER PAD 40x40cm       300
# 538554    581408     85175                           NaN        20
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Year  \
# 622    2010-12-01 11:52:00        0.0         NaN  United Kingdom  2010
# 1970   2010-12-01 14:32:00        0.0         NaN  United Kingdom  2010
# 1971   2010-12-01 14:33:00        0.0         NaN  United Kingdom  2010
# 1972   2010-12-01 14:33:00        0.0         NaN  United Kingdom  2010
# 1987   2010-12-01 14:34:00        0.0         NaN  United Kingdom  2010
# ...                    ...        ...         ...             ...   ...
# 535334 2011-12-07 18:36:00        0.0         NaN  United Kingdom  2011
# 536981 2011-12-08 10:33:00        0.0         NaN  United Kingdom  2011
# 538504 2011-12-08 13:58:00        0.0         NaN  United Kingdom  2011
# 538505 2011-12-08 13:58:00        0.0         NaN  United Kingdom  2011
# 538554 2011-12-08 14:06:00        0.0         NaN  United Kingdom  2011
#
#         Month  Day  Weekday WeekdayName  IsWeekend      Time  Hour  DayTime  \
# 622        12    1        3   Wednesday      False  11:52:00    11  Morning
# 1970       12    1        3   Wednesday      False  14:32:00    14     Noon
# 1971       12    1        3   Wednesday      False  14:33:00    14     Noon
# 1972       12    1        3   Wednesday      False  14:33:00    14     Noon
# 1987       12    1        3   Wednesday      False  14:34:00    14     Noon
# ...       ...  ...      ...         ...        ...       ...   ...      ...
# 535334     12    7        3   Wednesday      False  18:36:00    18      Eve
# 536981     12    8        4    Thursday      False  10:33:00    10  Morning
# 538504     12    8        4    Thursday      False  13:58:00    13     Noon
# 538505     12    8        4    Thursday      False  13:58:00    13     Noon
# 538554     12    8        4    Thursday      False  14:06:00    14     Noon
#
#         Sales
# 622       0.0
# 1970      0.0
# 1971      0.0
# 1972      0.0
# 1987      0.0
# ...       ...
# 535334    0.0
# 536981    0.0
# 538504    0.0
# 538505    0.0
# 538554    0.0
#
# [1163 rows x 18 columns]

# %%
#number of products having unit price to 0
print("# of rows having price 0 : ", len(data[data.UnitPrice == 0]))
print("# of products having price 0 : ", len(data[data.UnitPrice == 0]["StockCode"].unique()))
# Out:
# # of rows having price 0 :  1163
# # of products having price 0 :  675

# %% [markdown]
# Reducing country cardinalities

# %%
#Reducing cardinality for Country
data.loc[data["Country"].value_counts()[data["Country"]].values < 500, "Country"] = "Others"

# %% [markdown]
# Duplicates

# %%
data_dup = data.copy()
print("Percentage of suspect duplicated data: " , (data_orig.duplicated(["StockCode", "InvoiceNo"]).sum() / len(data)) * 100)
# Out:
# Percentage of suspect duplicated data:  2.01980864373744

# %%
duplicates = data_dup.loc[data_dup.duplicated()]
duplicates = duplicates.groupby(duplicates.columns.tolist(),as_index=False).size().sort_values("size", ascending = False)
size = duplicates.pop("size")
duplicates.insert(0, "size", size)
duplicates
# Out:
#       size InvoiceNo StockCode                          Description  Quantity  \
# 1596    19    555524     22698       PINK REGENCY TEACUP AND SAUCER         1
# 1595    11    555524     22697      GREEN REGENCY TEACUP AND SAUCER         1
# 3170     7    572861     22775  PURPLE DRAWERKNOB ACRYLIC EDWARDIAN        12
# 346      5    538514     21756             BATH BUILDING BLOCK WORD         1
# 470      5    540524     21756             BATH BUILDING BLOCK WORD         1
# ...    ...       ...       ...                                  ...       ...
# 1659     1    556280     22500     SET OF 2 TINS JARDIN DE PROVENCE         1
# 1658     1    556280     22497      SET OF 2 TINS VINTAGE BATHROOM          1
# 1657     1    556263     23242           TREASURE TIN BUFFALO BILL          1
# 1656     1    556252    84970S    HANGING HEART ZINC T-LIGHT HOLDER        12
# 4807     1    581538     23343         JUMBO BAG VINTAGE CHRISTMAS          1
#
#              InvoiceDate  UnitPrice  CustomerID         Country  Year  Month  \
# 1596 2011-06-05 11:37:00       2.95     16923.0  United Kingdom  2011      6
# 1595 2011-06-05 11:37:00       2.95     16923.0  United Kingdom  2011      6
# 3170 2011-10-26 12:46:00       1.25     14102.0  United Kingdom  2011     10
# 346  2010-12-12 14:27:00       5.95     15044.0  United Kingdom  2010     12
# 470  2011-01-09 12:53:00       5.95     16735.0  United Kingdom  2011      1
# ...                  ...        ...         ...             ...   ...    ...
# 1659 2011-06-09 20:03:00       4.95     14584.0  United Kingdom  2011      6
# 1658 2011-06-09 20:03:00       4.25     14584.0  United Kingdom  2011      6
# 1657 2011-06-09 18:41:00       2.08     13969.0  United Kingdom  2011      6
# 1656 2011-06-09 16:44:00       0.85     16779.0  United Kingdom  2011      6
# 4807 2011-12-09 11:34:00       2.08     14446.0  United Kingdom  2011     12
#
#       Day  Weekday WeekdayName  IsWeekend      Time  Hour  DayTime  Sales
# 1596    5        7      Sunday       True  11:37:00    11  Morning   2.95
# 1595    5        7      Sunday       True  11:37:00    11  Morning   2.95
# 3170   26        3   Wednesday      False  12:46:00    12  Morning  15.00
# 346    12        7      Sunday       True  14:27:00    14     Noon   5.95
# 470     9        7      Sunday       True  12:53:00    12  Morning   5.95
# ...   ...      ...         ...        ...       ...   ...      ...    ...
# 1659    9        4    Thursday      False  20:03:00    20      Eve   4.95
# 1658    9        4    Thursday      False  20:03:00    20      Eve   4.25
# 1657    9        4    Thursday      False  18:41:00    18      Eve   2.08
# 1656    9        4    Thursday      False  16:44:00    16     Noon  10.20
# 4807    9        5      Friday      False  11:34:00    11  Morning   2.08
#
# [4808 rows x 19 columns]

# %%
data[(data.InvoiceNo == "555524") & (data.StockCode == "22698")]
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 213176    555524     22698  PINK REGENCY TEACUP AND SAUCER         1
# 213177    555524     22698  PINK REGENCY TEACUP AND SAUCER         1
# 213183    555524     22698  PINK REGENCY TEACUP AND SAUCER         1
# 213191    555524     22698  PINK REGENCY TEACUP AND SAUCER         1
# 213192    555524     22698  PINK REGENCY TEACUP AND SAUCER         1
# 213194    555524     22698  PINK REGENCY TEACUP AND SAUCER         1
# 213195    555524     22698  PINK REGENCY TEACUP AND SAUCER         1
# 213196    555524     22698  PINK REGENCY TEACUP AND SAUCER         1
# 213197    555524     22698  PINK REGENCY TEACUP AND SAUCER         1
# 213198    555524     22698  PINK REGENCY TEACUP AND SAUCER         1
# 213199    555524     22698  PINK REGENCY TEACUP AND SAUCER         1
# 213200    555524     22698  PINK REGENCY TEACUP AND SAUCER         1
# 213201    555524     22698  PINK REGENCY TEACUP AND SAUCER         1
# 213202    555524     22698  PINK REGENCY TEACUP AND SAUCER         1
# 213203    555524     22698  PINK REGENCY TEACUP AND SAUCER         1
# 213204    555524     22698  PINK REGENCY TEACUP AND SAUCER         1
# 213205    555524     22698  PINK REGENCY TEACUP AND SAUCER         1
# 213206    555524     22698  PINK REGENCY TEACUP AND SAUCER         1
# 213207    555524     22698  PINK REGENCY TEACUP AND SAUCER         1
# 213208    555524     22698  PINK REGENCY TEACUP AND SAUCER         1
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Year  \
# 213176 2011-06-05 11:37:00       2.95     16923.0  United Kingdom  2011
# 213177 2011-06-05 11:37:00       2.95     16923.0  United Kingdom  2011
# 213183 2011-06-05 11:37:00       2.95     16923.0  United Kingdom  2011
# 213191 2011-06-05 11:37:00       2.95     16923.0  United Kingdom  2011
# 213192 2011-06-05 11:37:00       2.95     16923.0  United Kingdom  2011
# 213194 2011-06-05 11:37:00       2.95     16923.0  United Kingdom  2011
# 213195 2011-06-05 11:37:00       2.95     16923.0  United Kingdom  2011
# 213196 2011-06-05 11:37:00       2.95     16923.0  United Kingdom  2011
# 213197 2011-06-05 11:37:00       2.95     16923.0  United Kingdom  2011
# 213198 2011-06-05 11:37:00       2.95     16923.0  United Kingdom  2011
# 213199 2011-06-05 11:37:00       2.95     16923.0  United Kingdom  2011
# 213200 2011-06-05 11:37:00       2.95     16923.0  United Kingdom  2011
# 213201 2011-06-05 11:37:00       2.95     16923.0  United Kingdom  2011
# 213202 2011-06-05 11:37:00       2.95     16923.0  United Kingdom  2011
# 213203 2011-06-05 11:37:00       2.95     16923.0  United Kingdom  2011
# 213204 2011-06-05 11:37:00       2.95     16923.0  United Kingdom  2011
# 213205 2011-06-05 11:37:00       2.95     16923.0  United Kingdom  2011
# 213206 2011-06-05 11:37:00       2.95     16923.0  United Kingdom  2011
# 213207 2011-06-05 11:37:00       2.95     16923.0  United Kingdom  2011
# 213208 2011-06-05 11:37:00       2.95     16923.0  United Kingdom  2011
#
#         Month  Day  Weekday WeekdayName  IsWeekend      Time  Hour  DayTime  \
# 213176      6    5        7      Sunday       True  11:37:00    11  Morning
# 213177      6    5        7      Sunday       True  11:37:00    11  Morning
# 213183      6    5        7      Sunday       True  11:37:00    11  Morning
# 213191      6    5        7      Sunday       True  11:37:00    11  Morning
# 213192      6    5        7      Sunday       True  11:37:00    11  Morning
# 213194      6    5        7      Sunday       True  11:37:00    11  Morning
# 213195      6    5        7      Sunday       True  11:37:00    11  Morning
# 213196      6    5        7      Sunday       True  11:37:00    11  Morning
# 213197      6    5        7      Sunday       True  11:37:00    11  Morning
# 213198      6    5        7      Sunday       True  11:37:00    11  Morning
# 213199      6    5        7      Sunday       True  11:37:00    11  Morning
# 213200      6    5        7      Sunday       True  11:37:00    11  Morning
# 213201      6    5        7      Sunday       True  11:37:00    11  Morning
# 213202      6    5        7      Sunday       True  11:37:00    11  Morning
# 213203      6    5        7      Sunday       True  11:37:00    11  Morning
# 213204      6    5        7      Sunday       True  11:37:00    11  Morning
# 213205      6    5        7      Sunday       True  11:37:00    11  Morning
# 213206      6    5        7      Sunday       True  11:37:00    11  Morning
# 213207      6    5        7      Sunday       True  11:37:00    11  Morning
# 213208      6    5        7      Sunday       True  11:37:00    11  Morning
#
#         Sales
# 213176   2.95
# 213177   2.95
# 213183   2.95
# 213191   2.95
# 213192   2.95
# 213194   2.95
# 213195   2.95
# 213196   2.95
# 213197   2.95
# 213198   2.95
# 213199   2.95
# 213200   2.95
# 213201   2.95
# 213202   2.95
# 213203   2.95
# 213204   2.95
# 213205   2.95
# 213206   2.95
# 213207   2.95
# 213208   2.95

# %%
#replacing duplicates with single record containing sum of all quantities for records that are going to be deleted
# tested, it works
data['Quantity'] = data.groupby(['InvoiceNo', 'StockCode'])['Quantity'].transform('sum')
data = data.drop_duplicates(subset=['InvoiceNo', 'StockCode'])

# %%
data[(data.InvoiceNo == "555524") & (data.StockCode == "22698")]
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 213176    555524     22698  PINK REGENCY TEACUP AND SAUCER        20
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Year  \
# 213176 2011-06-05 11:37:00       2.95     16923.0  United Kingdom  2011
#
#         Month  Day  Weekday WeekdayName  IsWeekend      Time  Hour  DayTime  \
# 213176      6    5        7      Sunday       True  11:37:00    11  Morning
#
#         Sales
# 213176   2.95

# %%
data["TotalPrice"] = data["UnitPrice"] * data["Quantity"]
data.drop("Sales", axis = 1, inplace = True)

# %% [markdown]
# ABC segmentation

# %%
abc_transactions = abc_analysis(data["TotalPrice"], True, fltSize=10)

# index position of A, B, and C for transactions
transaction_a_index = abc_transactions['Aind']
transaction_b_index = abc_transactions['Bind']
transaction_c_index = abc_transactions['Cind']

# New Column indicating A, B, or C
condition = [data.index.isin(transaction_a_index),
             data.index.isin(transaction_b_index),
             data.index.isin(transaction_c_index)]

segment_list = ['A','B','C']

data['Transaction_ABC'] = np.select(condition, segment_list)
data.sort_values(by=['TotalPrice'], ascending=True)
abc_transactions
# Out:
# {'ABLimit': 19.5,
#  'BCLimit': 14.040000000000001,
#  'ABexchanged': True,
#  'Aind': [1,
#   2,
#   3,
#   4,
#   6,
#   9,
#   12,
#   14,
#   16,
#   19,
#   20,
#   21,
#   26,
#   27,
#   28,
#   31,
#   32,
#   33,
#   34,
#   35,
#   36,
#   37,
#   39,
#   40,
#   41,
#   44,
#   45,
#   49,
#   50,
#   51,
#   57,
#   60,
#   61,
#   63,
#   64,
#   66,
#   67,
#   68,
#   74,
#   77,
#   78,
#   80,
#   81,
#   82,
#   87,
#   89,
#   90,
#   95,
#   100,
#   101,
#   104,
#   105,
#   106,
#   110,
#   111,
#   137,
#   138,
#   140,
#   141,
#   143,
#   144,
#   145,
#   147,
#   148,
#   149,
#   150,
#   152,
#   153,
#   155,
#   156,
#   157,
#   159,
#   162,
#   163,
#   164,
#   166,
#   171,
#   172,
#   173,
#   174,
#   175,
#   176,
#   177,
#   178,
#   185,
#   190,
#   191,
#   192,
#   193,
#   194,
#   196,
#   197,
#   198,
#   205,
#   206,
#   208,
#   210,
#   211,
#   212,
#   213,
#   214,
#   215,
#   216,
#   217,
#   218,
#   219,
#   220,
#   221,
#   222,
#   223,
#   224,
#   225,
#   226,
#   227,
#   228,
#   229,
#   230,
#   235,
#   238,
#   239,
#   241,
#   243,
#   244,
#   245,
#   246,
#   247,
#   248,
#   249,
#   250,
#   251,
#   252,
#   253,
#   254,
#   258,
#   261,
#   262,
#   263,
#   264,
#   265,
#   266,
#   268,
#   269,
#   270,
#   271,
#   277,
#   279,
#   280,
#   281,
#   283,
#   284,
#   285,
#   286,
#   289,
#   290,
#   291,
#   293,
#   294,
#   295,
#   297,
#   298,
#   300,
#   301,
#   303,
#   321,
#   364,
#   371,
#   372,
#   373,
#   374,
#   375,
#   380,
#   381,
#   393,
#   402,
#   403,
#   404,
#   405,
#   406,
#   407,
#   412,
#   413,
#   416,
#   417,
#   419,
#   420,
#   426,
#   430,
#   435,
#   436,
#   440,
#   444,
#   449,
#   450,
#   456,
#   460,
#   463,
#   465,
#   467,
#   470,
#   471,
#   541,
#   543,
#   544,
#   562,
#   563,
#   607,
#   608,
#   635,
#   637,
#   638,
#   639,
#   640,
#   647,
#   648,
#   658,
#   659,
#   660,
#   661,
#   662,
#   663,
#   664,
#   665,
#   667,
#   668,
#   674,
#   677,
#   678,
#   679,
#   680,
#   682,
#   683,
#   684,
#   685,
#   686,
#   687,
#   688,
#   693,
#   705,
#   707,
#   708,
#   709,
#   710,
#   711,
#   715,
#   717,
#   719,
#   720,
#   722,
#   725,
#   726,
#   729,
#   805,
#   807,
#   808,
#   809,
#   810,
#   811,
#   812,
#   814,
#   815,
#   816,
#   817,
#   818,
#   819,
#   823,
#   852,
#   862,
#   865,
#   866,
#   867,
#   871,
#   872,
#   873,
#   874,
#   875,
#   877,
#   878,
#   916,
#   995,
#   1006,
#   1016,
#   1023,
#   1024,
#   1025,
#   1027,
#   1028,
#   1029,
#   1032,
#   1036,
#   1037,
#   1038,
#   1044,
#   1055,
#   1090,
#   1092,
#   1099,
#   1104,
#   1110,
#   1116,
#   1126,
#   1127,
#   1128,
#   1129,
#   1132,
#   1133,
#   1134,
#   1135,
#   3917,
#   3919,
#   3922,
#   3923,
#   3932,
#   3940,
#   3975,
#   3999,
#   4009,
#   4018,
#   4020,
#   4030,
#   4102,
#   4124,
#   4129,
#   4130,
#   4131,
#   4132,
#   4133,
#   4135,
#   4136,
#   4139,
#   4140,
#   4142,
#   4143,
#   4145,
#   4146,
#   4147,
#   4148,
#   4149,
#   4150,
#   4151,
#   4152,
#   4153,
#   4156,
#   4157,
#   4158,
#   4169,
#   4174,
#   4175,
#   4182,
#   4188,
#   4190,
#   4196,
#   4197,
#   4199,
#   4200,
#   4201,
#   4205,
#   4207,
#   4211,
#   4213,
#   4214,
#   4216,
#   4218,
#   4224,
#   4225,
#   4227,
#   4228,
#   4229,
#   4230,
#   4231,
#   4236,
#   4237,
#   4243,
#   4248,
#   4249,
#   4257,
#   4258,
#   4259,
#   4260,
#   4261,
#   4262,
#   4263,
#   4264,
#   4265,
#   4266,
#   4281,
#   4294,
#   4305,
#   4309,
#   4318,
#   4319,
#   4321,
#   4327,
#   4328,
#   4332,
#   4341,
#   4349,
#   4352,
#   4368,
#   4377,
#   4378,
#   4379,
#   4381,
#   4382,
#   4383,
#   4384,
#   4385,
#   4386,
#   4442,
#   4495,
#   4500,
#   4506,
#   4507,
#   4514,
#   4543,
#   4544,
#   4546,
#   4547,
#   4549,
#   4550,
#   4556,
#   4557,
#   4563,
#   4564,
#   4565,
#   4566,
#   4569,
#   4570,
#   4572,
#   4574,
#   4575,
#   4576,
#   4577,
#   4579,
#   4580,
#   4581,
#   4584,
#   4602,
#   4603,
#   4607,
#   4609,
#   4618,
#   4619,
#   4620,
#   4621,
#   4626,
#   4627,
#   4628,
#   4629,
#   4630,
#   4631,
#   4632,
#   4635,
#   4641,
#   4642,
#   4643,
#   4646,
#   4650,
#   4651,
#   4655,
#   4663,
#   4664,
#   4665,
#   4666,
#   4669,
#   4670,
#   4672,
#   4674,
#   4675,
#   4683,
#   4684,
#   4685,
#   4688,
#   4697,
#   4709,
#   4712,
#   4713,
#   4714,
#   4723,
#   4725,
#   4727,
#   4730,
#   4732,
#   4733,
#   4734,
#   4738,
#   4739,
#   4740,
#   4741,
#   4742,
#   4745,
#   4754,
#   4755,
#   4758,
#   4768,
#   4787,
#   4789,
#   4790,
#   4791,
#   4793,
#   4799,
#   4814,
#   4823,
#   4824,
#   4825,
#   4828,
#   4833,
#   4839,
#   4845,
#   4846,
#   4848,
#   4850,
#   4852,
#   4853,
#   4854,
#   4855,
#   4856,
#   4858,
#   4865,
#   4873,
#   4876,
#   4879,
#   4880,
#   4914,
#   4918,
#   4948,
#   4951,
#   4978,
#   4979,
#   4981,
#   4982,
#   5007,
#   5011,
#   5014,
#   5017,
#   5029,
#   5030,
#   5031,
#   5032,
#   5033,
#   5036,
#   5037,
#   5040,
#   5041,
#   5042,
#   5044,
#   5045,
#   5050,
#   5051,
#   5052,
#   5065,
#   5073,
#   5086,
#   5093,
#   5095,
#   5105,
#   5106,
#   5110,
#   5113,
#   5114,
#   5120,
#   5125,
#   5131,
#   5136,
#   5148,
#   5158,
#   5166,
#   5168,
#  4       0.148416
#            ...
#  996     0.999970
#  997     0.999990
#  998     1.000000
#  999     1.000000
#  1000    1.000000
#  Name: Yield, Length: 1001, dtype: float64,
#  'A': {'Effort': 0.226, 'Yield': 0.6829944607980788},
#  'B': {'Effort': 0.259, 'Yield': 0.7136005701534663},
#  'C': {'Effort': 0.389, 'Yield': 0.8199978225834241},
#  'CleanedData': 0         15.30
#  1         20.34
#  2         22.00
#  3         20.34
#  4         20.34
#            ...
#  518454    10.20
#  518455    12.60
#  518456    16.60
#  518457    16.60
#  518458    14.85
#  Name: TotalPrice, Length: 518459, dtype: float64}

# %%
customer_values = data[["CustomerID", "TotalPrice"]].groupby("CustomerID").sum("TotalPrice").sort_values("TotalPrice", ascending = False)
abc_customers = abc_analysis(customer_values["TotalPrice"], True, fltSize=10)

# index position of A, B, and C for transactions
customer_a_index = customer_values.iloc[abc_customers['Aind']].index
customer_b_index = customer_values.iloc[abc_customers['Bind']].index
customer_c_index = customer_values.iloc[abc_customers['Cind']].index

# New Column indicating A, B, or C
condition = [data["CustomerID"].isin(customer_a_index),
             data["CustomerID"].isin(customer_b_index),
             data["CustomerID"].isin(customer_c_index) | data["CustomerID"].isna()]

segment_list = ['A','B','C']

data['Customer_ABC'] = np.select(condition, segment_list)
data.sort_values(by=['TotalPrice'], ascending=True)

# BEWARE WE HAVE SOME NaNs for these values --> might not be the most accurate classification
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 41492     539856     22372  AIRLINE BAG VINTAGE WORLD CHAMPION          1
# 299545    563106     21658                                  NaN         3
# 175253    551900     20778                                  NaN         2
# 160541    550460    47556B  did  a credit  and did not tick ret      1300
# 299550    563108     21033                                  NaN        37
# ...          ...       ...                                  ...       ...
# 52709     540815    85123A   WHITE HANGING HEART T-LIGHT HOLDER      1930
# 421601    573003     23084                   RABBIT NIGHT LIGHT      2400
# 52711     540815     21108   FAIRY CAKE FLANNEL ASSORTED COLOUR      3114
# 160546    550461     21108   FAIRY CAKE FLANNEL ASSORTED COLOUR      3114
# 348325    567423     23243  SET OF TEA COFFEE SUGAR TINS PANTRY      1412
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Year  \
# 41492  2010-12-22 14:41:00       0.00         NaN  United Kingdom  2010
# 299545 2011-08-12 10:15:00       0.00         NaN  United Kingdom  2011
# 175253 2011-05-05 10:45:00       0.00         NaN  United Kingdom  2011
# 160541 2011-04-18 13:18:00       0.00         NaN  United Kingdom  2011
# 299550 2011-08-12 10:18:00       0.00         NaN  United Kingdom  2011
# ...                    ...        ...         ...             ...   ...
# 52709  2011-01-11 12:55:00       2.55     15749.0  United Kingdom  2011
# 421601 2011-10-27 12:11:00       2.08     14646.0     Netherlands  2011
# 52711  2011-01-11 12:55:00       2.10     15749.0  United Kingdom  2011
# 160546 2011-04-18 13:20:00       2.10     15749.0  United Kingdom  2011
# 348325 2011-09-20 11:05:00       5.06     17450.0  United Kingdom  2011
#
#         Month  Day  Weekday WeekdayName  IsWeekend      Time  Hour  DayTime  \
# 41492      12   22        3   Wednesday      False  14:41:00    14     Noon
# 299545      8   12        5      Friday      False  10:15:00    10  Morning
# 175253      5    5        4    Thursday      False  10:45:00    10  Morning
# 160541      4   18        1      Monday      False  13:18:00    13     Noon
# 299550      8   12        5      Friday      False  10:18:00    10  Morning
# ...       ...  ...      ...         ...        ...       ...   ...      ...
# 52709       1   11        2     Tuesday      False  12:55:00    12  Morning
# 421601     10   27        4    Thursday      False  12:11:00    12  Morning
# 52711       1   11        2     Tuesday      False  12:55:00    12  Morning
# 160546      4   18        1      Monday      False  13:20:00    13     Noon
# 348325      9   20        2     Tuesday      False  11:05:00    11  Morning
#
#         TotalPrice Transaction_ABC Customer_ABC
# 41492         0.00               C            C
# 299545        0.00               C            C
# 175253        0.00               C            C
# 160541        0.00               A            C
# 299550        0.00               C            C
# ...            ...             ...          ...
# 52709      4921.50               C            A
# 421601     4992.00               A            A
# 52711      6539.40               C            A
# 160546     6539.40               C            A
# 348325     7144.72               C            A
#
# [518459 rows x 20 columns]

# %%
product_values = data[["TotalPrice", "StockCode"]].groupby("StockCode").sum("TotalPrice").sort_values("TotalPrice", ascending = False)
abc_products = abc_analysis(product_values["TotalPrice"], True, fltSize=10)

# # # index position of A, B, and C for transactions
product_a_index = product_values.iloc[abc_products['Aind']].index
product_b_index = product_values.iloc[abc_products['Bind']].index
product_c_index = product_values.iloc[abc_products['Cind']].index

# # New Column indicating A, B, or C
condition = [data["StockCode"].isin(product_a_index),
             data["StockCode"].isin(product_b_index),
             data["StockCode"].isin(product_c_index)]

segment_list = ['A','B','C']

data['Product_ABC'] = np.select(condition, segment_list)
data.sort_values(by=['TotalPrice'], ascending=True)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 41492     539856     22372  AIRLINE BAG VINTAGE WORLD CHAMPION          1
# 299545    563106     21658                                  NaN         3
# 175253    551900     20778                                  NaN         2
# 160541    550460    47556B  did  a credit  and did not tick ret      1300
# 299550    563108     21033                                  NaN        37
# ...          ...       ...                                  ...       ...
# 52709     540815    85123A   WHITE HANGING HEART T-LIGHT HOLDER      1930
# 421601    573003     23084                   RABBIT NIGHT LIGHT      2400
# 52711     540815     21108   FAIRY CAKE FLANNEL ASSORTED COLOUR      3114
# 160546    550461     21108   FAIRY CAKE FLANNEL ASSORTED COLOUR      3114
# 348325    567423     23243  SET OF TEA COFFEE SUGAR TINS PANTRY      1412
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Year  \
# 41492  2010-12-22 14:41:00       0.00         NaN  United Kingdom  2010
# 299545 2011-08-12 10:15:00       0.00         NaN  United Kingdom  2011
# 175253 2011-05-05 10:45:00       0.00         NaN  United Kingdom  2011
# 160541 2011-04-18 13:18:00       0.00         NaN  United Kingdom  2011
# 299550 2011-08-12 10:18:00       0.00         NaN  United Kingdom  2011
# ...                    ...        ...         ...             ...   ...
# 52709  2011-01-11 12:55:00       2.55     15749.0  United Kingdom  2011
# 421601 2011-10-27 12:11:00       2.08     14646.0     Netherlands  2011
# 52711  2011-01-11 12:55:00       2.10     15749.0  United Kingdom  2011
# 160546 2011-04-18 13:20:00       2.10     15749.0  United Kingdom  2011
# 348325 2011-09-20 11:05:00       5.06     17450.0  United Kingdom  2011
#
#         Month  ...  WeekdayName  IsWeekend      Time  Hour  DayTime    Sales  \
# 41492      12  ...    Wednesday      False  14:41:00    14     Noon     0.00
# 299545      8  ...       Friday      False  10:15:00    10  Morning     0.00
# 175253      5  ...     Thursday      False  10:45:00    10  Morning     0.00
# 160541      4  ...       Monday      False  13:18:00    13     Noon     0.00
# 299550      8  ...       Friday      False  10:18:00    10  Morning     0.00
# ...       ...  ...          ...        ...       ...   ...      ...      ...
# 52709       1  ...      Tuesday      False  12:55:00    12  Morning  4921.50
# 421601     10  ...     Thursday      False  12:11:00    12  Morning  4992.00
# 52711       1  ...      Tuesday      False  12:55:00    12  Morning  6539.40
# 160546      4  ...       Monday      False  13:20:00    13     Noon  6539.40
# 348325      9  ...      Tuesday      False  11:05:00    11  Morning  7144.72
#
#        TotalPrice  Transaction_ABC  Customer_ABC Product_ABC
# 41492        0.00                C             0           C
# 299545       0.00                C             0           A
# 175253       0.00                C             0           C
# 160541       0.00                A             0           A
# 299550       0.00                C             0           A
# ...           ...              ...           ...         ...
# 52709     4921.50                C             A           A
# 421601    4992.00                A             A           A
# 52711     6539.40                C             A           A
# 160546    6539.40                C             A           A
# 348325    7144.72                C             A           A
#
# [518459 rows x 22 columns]

# %% [markdown]
# ## A priori algorithm

# %%
# Stripping extra spaces in the description
data['Description'] = data['Description'].str.strip()
 
# Dropping the rows without any invoice number
data.dropna(axis = 0, subset =['InvoiceNo'], inplace = True)
data['InvoiceNo'] = data['InvoiceNo'].astype('str')
 
# Dropping all transactions which were done on credit
data = data[~data['InvoiceNo'].str.contains('C')]

# %% [markdown]
# # UK

# %%
# Transactions done in the United Kingdom
basket_uk = (data[data['Country'] =="United Kingdom"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
def hot_encode(x):
    if(x<= 0):
        return 0
    if(x>= 1):
        return 1

basket_uk = basket_uk.applymap(hot_encode)

# %%
frq_items = apriori(basket_uk, min_support = 0.03, use_colnames = True)

# %%
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])

rules.head()
# Out:
#                           antecedents                        consequents  \
# 2    (PINK REGENCY TEACUP AND SAUCER)  (GREEN REGENCY TEACUP AND SAUCER)
# 18   (PINK REGENCY TEACUP AND SAUCER)  (ROSES REGENCY TEACUP AND SAUCER)
# 4   (GREEN REGENCY TEACUP AND SAUCER)  (ROSES REGENCY TEACUP AND SAUCER)
# 5   (ROSES REGENCY TEACUP AND SAUCER)  (GREEN REGENCY TEACUP AND SAUCER)
# 8           (JUMBO BAG PINK POLKADOT)          (JUMBO BAG RED RETROSPOT)
#
#     antecedent support  consequent support   support  confidence       lift  \
# 2             0.038863            0.051634  0.031898    0.820768  15.896012
# 18            0.038863            0.052905  0.030184    0.776671  14.680469
# 4             0.051634            0.052905  0.038753    0.750535  14.186451
# 5             0.052905            0.051634  0.038753    0.732497  14.186451
# 8             0.064072            0.107137  0.043397    0.677308   6.321891
#
#     leverage  conviction
# 2   0.029891    5.291282
# 18  0.028128    4.240814
# 4   0.036021    3.796509
# 5   0.036021    3.545260
# 8   0.036532    2.766921

# %%
len(rules)
# Out:
# 20

# %% [markdown]
# # Netherlands

# %%
# Transactions done in the Netherlands
basket_net = (data[data['Country'] =="Netherlands"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
def hot_encode(x):
    if(x<= 0):
        return 0
    if(x>= 1):
        return 1

basket_net = basket_net.applymap(hot_encode)

# %%
frq_items = apriori(basket_net, min_support = 0.05, use_colnames = True)

# %%
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])

rules.head(6)
# Out:
#                                             antecedents  \
# 650                      (FOLDING BUTTERFLY MIRROR RED)
# 651                 (FOLDING BUTTERFLY MIRROR HOT PINK)
# 1352  (CARD DOLLY GIRL, FOOD CONTAINER SET 3 LOVE HE...
# 1353                           (10 COLOUR SPACEBOY PEN)
# 1382  (CARD DOLLY GIRL, STRAWBERRY LUNCH BOX WITH CU...
# 1383                           (10 COLOUR SPACEBOY PEN)
#
#                                             consequents  antecedent support  \
# 650                 (FOLDING BUTTERFLY MIRROR HOT PINK)            0.053191
# 651                      (FOLDING BUTTERFLY MIRROR RED)            0.053191
# 1352                           (10 COLOUR SPACEBOY PEN)            0.053191
# 1353  (CARD DOLLY GIRL, FOOD CONTAINER SET 3 LOVE HE...            0.053191
# 1382                           (10 COLOUR SPACEBOY PEN)            0.053191
# 1383  (CARD DOLLY GIRL, STRAWBERRY LUNCH BOX WITH CU...            0.053191
#
#       consequent support   support  confidence  lift  leverage  conviction
# 650             0.053191  0.053191         1.0  18.8  0.050362         inf
# 651             0.053191  0.053191         1.0  18.8  0.050362         inf
# 1352            0.053191  0.053191         1.0  18.8  0.050362         inf
# 1353            0.053191  0.053191         1.0  18.8  0.050362         inf
# 1382            0.053191  0.053191         1.0  18.8  0.050362         inf
# 1383            0.053191  0.053191         1.0  18.8  0.050362         inf

# %%
len(rules)

# %% [markdown]
# # Germany

# %%
# Transactions done in GErmany
basket_ger = (data[data['Country'] =="Germany"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
def hot_encode(x):
    if(x<= 0):
        return 0
    if(x>= 1):
        return 1

basket_ger = basket_ger.applymap(hot_encode)

# %%
frq_items = apriori(basket_ger, min_support = 0.03, use_colnames = True)

# %%
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])

rules.head()
# Out:
#                                            antecedents  \
# 179  (RED RETROSPOT CHARLOTTE BAG, ROUND SNACK BOXE...
# 184  (ROUND SNACK BOXES SET OF 4 FRUITS, SPACEBOY L...
# 27                            (JAM JAR WITH GREEN LID)
# 33                           (JUMBO BAG PINK POLKADOT)
# 142  (ROUND SNACK BOXES SET OF 4 FRUITS, CHARLOTTE ...
#
#                               consequents  antecedent support  \
# 179              (WOODLAND CHARLOTTE BAG)            0.031603
# 184  (ROUND SNACK BOXES SET OF4 WOODLAND)            0.040632
# 27                (JAM JAR WITH PINK LID)            0.036117
# 33              (JUMBO BAG RED RETROSPOT)            0.036117
# 142  (ROUND SNACK BOXES SET OF4 WOODLAND)            0.033860
#
#      consequent support   support  confidence       lift  leverage  conviction
# 179            0.130926  0.031603    1.000000   7.637931  0.027465         inf
# 184            0.252822  0.038375    0.944444   3.735615  0.028102   13.449210
# 27             0.065463  0.033860    0.937500  14.321121  0.031496   14.952596
# 33             0.081264  0.033860    0.937500  11.536458  0.030925   14.699774
# 142            0.252822  0.031603    0.933333   3.691667  0.023042   11.207675

# %%
len(rules)
# Out:
# 196

# %% [markdown]
# # ITALY

# %%
# Transactions done in GErmany
basket_ita = (data[data['Country'] =="Italy"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
def hot_encode(x):
    if(x<= 0):
        return 0
    if(x>= 1):
        return 1

basket_ita = basket_ita.applymap(hot_encode)

# %%
frq_items = apriori(basket_ita, min_support = 0.03, use_colnames = True)

# %%
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])

rules.head(6)
# Out:
#                            antecedents                        consequents  \
# 22   (BAKING MOULD CHOCOLATE CUPCAKES)         (RED LOVE HEART SHAPE CUP)
# 23          (RED LOVE HEART SHAPE CUP)  (BAKING MOULD CHOCOLATE CUPCAKES)
# 50          (HOME BUILDING BLOCK WORD)         (BATH BUILDING BLOCK WORD)
# 51          (BATH BUILDING BLOCK WORD)         (HOME BUILDING BLOCK WORD)
# 160      (CHRISTMAS CRAFT WHITE FAIRY)   (CHRISTMAS CRAFT LITTLE FRIENDS)
# 161   (CHRISTMAS CRAFT LITTLE FRIENDS)      (CHRISTMAS CRAFT WHITE FAIRY)
#
#      antecedent support  consequent support   support  confidence  lift  \
# 22             0.057143            0.057143  0.057143         1.0  17.5
# 23             0.057143            0.057143  0.057143         1.0  17.5
# 50             0.057143            0.057143  0.057143         1.0  17.5
# 51             0.057143            0.057143  0.057143         1.0  17.5
# 160            0.057143            0.057143  0.057143         1.0  17.5
# 161            0.057143            0.057143  0.057143         1.0  17.5
#
#      leverage  conviction
# 22   0.053878         inf
# 23   0.053878         inf
# 50   0.053878         inf
# 51   0.053878         inf
# 160  0.053878         inf
# 161  0.053878         inf

# %%
len(rules)
# Out:
# 4939794

# %% [markdown]
# # Suggestion Models

# %% [markdown]
# ## Part 1

# %%
popular_products = pd.DataFrame(data.groupby('StockCode')['Quantity'].sum())
most_popular = popular_products.sort_values('Quantity', ascending=False)
most_popular.head(10)

# %%
most_popular.head(30).plot(kind = "bar")

# %%
popular_products = pd.DataFrame(data.groupby('Description')['Quantity'].sum())
most_popular = popular_products.sort_values('Quantity', ascending=False)
most_popular.head(10)

# %%
most_popular.head(30).plot(kind = "bar")

# %%
data[data["StockCode"]=="22197"].value_counts("Description")

# %% [markdown]
# ## Part 2

# %%
data1 = data.head(10000)

# %%
data["InvoiceNo"].nunique()

# %%
test = pd.DataFrame(data["InvoiceNo"].value_counts())

# %%
test[test["InvoiceNo"]>1]

# %%
df = data[["InvoiceNo","StockCode"]]
df["flag"] = 1
df

# %%
price_utility_matrix = df.pivot_table(index='InvoiceNo', columns='StockCode', fill_value=0)
price_utility_matrix

# %%
test = pd.DataFrame(price_utility_matrix)
test

# %%
test.iloc[0,:].value_counts()

# %%
data[data["InvoiceNo"]=="536365"]

# %%
# price_utility_matrix = data1.pivot_table(values='TotalPrice', index=data1.index, columns='StockCode', fill_value=0)
# price_utility_matrix.head()

# %%
price_utility_matrix.shape

# %%
type(price_utility_matrix)

# %%
X = price_utility_matrix.T
X.head()

# %%
X.reset_index(inplace=True)
X.set_index("StockCode",inplace=True)
X.drop("level_0",axis=1,inplace=True)
X

# %%
X1 = X

# %%
SVD = TruncatedSVD(n_components=10)
decomposed_matrix = SVD.fit_transform(X)
decomposed_matrix.shape

# %%
correlation_matrix = np.corrcoef(decomposed_matrix)
correlation_matrix.shape

# %%
X.index[999]

# %%
i = "22076"

product_names = list(X.index)
product_ID = product_names.index(i)
product_ID

# %%
correlation_product_ID = correlation_matrix[product_ID]
correlation_product_ID.shape

# %%
Recommend = list(X.index[correlation_product_ID > 0.90])

# Removes the item already bought by the customer
Recommend.remove(i) 

Recommend[0:9]

# %%
def item_recommender(stockcode):
    
    
    if stockcode in list(X.index):
        l_description = []
        stockcode = str(stockcode)
        product_names = list(X.index)
        product_ID = product_names.index(stockcode)
        correlation_product_ID = correlation_matrix[product_ID]
        Recommend = list(X.index[correlation_product_ID > 0.90])

        # Removes the item already bought by the customer
        Recommend.remove(stockcode) 
        Recommend = Recommend[0:9]
        print(stockcode)
        print(data[data["StockCode"]==stockcode]["Description"].iloc[0])
        print(Recommend)

        for j in Recommend:
            x = data[data["StockCode"]==j]["Description"].iloc[0]
            l_description.append(x)

        return l_description
    
    else:
        print("No Recommendation")

# %%
X.index

# %%
item_recommender("10002")

# %%
item_recommender("20818")

# %%
item_recommender("21261")

# %%
item_recommender("17011F")

# %%
item_recommender("21069")

# %%
item_recommender("22076")

# %%
data[data["StockCode"]=="22076"]["Description"].iloc[0]

# %%
data[data["StockCode"]=="22076"]

# %%
data[data["StockCode"]=="20857"]

# %% [markdown]
# ## Part 3

# %%
product_descriptions = data[["StockCode","Description"]].dropna()
product_descriptions

# %%
# product_descriptions1 = product_descriptions.head(10000)

product_descriptions1 = product_descriptions.copy()

# product_descriptions1.iloc[:,1]

product_descriptions1["Description"].head(10)

# %%
vectorizer = TfidfVectorizer(stop_words='english')
X1 = vectorizer.fit_transform(product_descriptions1["Description"])
X1

# %%
# # Fitting K-Means to the dataset

# X=X1

# kmeans = KMeans(n_clusters = 50, init = 'k-means++')
# y_kmeans = kmeans.fit_predict(X)
# plt.plot(y_kmeans, ".")
# plt.show()

# %%
def print_cluster(i):
    print("Cluster %d:" % i),
    for ind in order_centroids[i, :10]:
        print(' %s' % terms[ind]),
    print

# %%
# # Optimal clusters is 

true_k = 10

model = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
model.fit(X1)

print("Top terms per cluster:")
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()
for i in range(true_k):
    print_cluster(i)

# %%
def show_recommendations(product):
    #print("Cluster ID:")
    Y = vectorizer.transform([product])
    prediction = model.predict(Y)
    #print(prediction)
    print_cluster(prediction[0])

# %%
show_recommendations("easter")

# %%
show_recommendations("car")

# %%
show_recommendations("knife")

# %%
show_recommendations("popcorn")
