# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
import re
import pickle

from sklearn.metrics import f1_score, accuracy_score
from sklearn.preprocessing import MinMaxScaler, StandardScaler, OneHotEncoder,LabelEncoder,MaxAbsScaler,RobustScaler

from sklearn.preprocessing import MinMaxScaler, StandardScaler, OneHotEncoder,LabelEncoder,MaxAbsScaler,RobustScaler
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, StratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.dummy import DummyClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier,ExtraTreesClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report,confusion_matrix
from keras.models import Sequential
from numpy import loadtxt
from keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
import phik

import warnings
warnings.filterwarnings('ignore')


RANDOM_STATE = 42
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 21>()
#      19 from sklearn.metrics import confusion_matrix
#      20 from sklearn.metrics import classification_report,confusion_matrix
# ---> 21 from keras.models import Sequential
#      22 from numpy import loadtxt
#      23 from keras.layers import Dense
#
# ModuleNotFoundError: No module named 'keras'

# %% [markdown]
# ### Definition of Functions

# %%
def metrics(y_train, pred_train , y_val, pred_val):
    """
    Function that pritns the classification report and the confusion matrix of the train and validation dataset
    """
    print('___________________________________________________________________________________________________________')
    print('                                                     TRAIN                                                 ')
    print('-----------------------------------------------------------------------------------------------------------')
    print(classification_report(y_train, pred_train))
    print(confusion_matrix(y_train, pred_train))


    print('___________________________________________________________________________________________________________')
    print('                                                VALIDATION                                                 ')
    print('-----------------------------------------------------------------------------------------------------------')
    print(classification_report(y_val, pred_val))
    print(confusion_matrix(y_val, pred_val))

# %%
def micro_f1_score(y_train, pred_train , y_val, pred_val):
    """
    Function that pritns the micro f1 score of the train and validation dataset
    """
    print('_____________________________________')
    print('                                                     TRAIN                                                 ')
    print('-----------------------------------------------------------------------------------------------------------')
    print(f1_score(y_train, pred_train, average='micro'))

    print('_____________________________________')
    print('                                                VALIDATION                                                 ')
    print('-----------------------------------------------------------------------------------------------------------')
    print(f1_score(y_val, pred_val, average='micro'))
    return f1_score(y_val, pred_val, average='micro')

# %%
def best_scale(model,X_train,y_train,X_test,y_test):
    """
    Function that returns a table with the micro f1 score for the different scaler
    """
    standard=StandardScaler().fit(X_train).transform(X_train)
    standardTest=StandardScaler().fit(X_test).transform(X_test)

    minMax=MinMaxScaler().fit(X_train).transform(X_train)
    minMaxTest=MinMaxScaler().fit(X_test).transform(X_test)

    maxAbs=MaxAbsScaler().fit(X_train).transform(X_train)
    maxAbsTest=MaxAbsScaler().fit(X_test).transform(X_test)
        
    robust=RobustScaler().fit(X_train).transform(X_train)
    robustTest=RobustScaler().fit(X_test).transform(X_test)

    sclares=[standard,minMax,maxAbs,robust,X_train]
    sclaresTest=[standardTest,minMaxTest,maxAbsTest,robustTest,X_test]
    
    f_score=[]
    
    for i in range(len(sclares)):
        model.fit(sclares[i],y_train)
        y_pred=model.predict(sclaresTest[i])
        f_score.append(f1_score(y_pred,y_test,average="micro"))
        

    return pd.DataFrame(f_score,index=["Standard","MinMax","MaxAbs","Robust","No Scaler"], columns=["F1 Score"])

# %%
def bar_charts_categorical(df, feature, target):
    """
    Function that plots the frequency and the importance that a categorical variable has with the target
    """
    cont_tab = pd.crosstab(df[feature], df[target], margins = True)
    categories = cont_tab.index[:-1]
        
    fig = plt.figure(figsize=(15, 5))
    
    plt.subplot(121)
    p1 = plt.bar(categories, cont_tab.iloc[:-1, 0].values, 0.55, color="lightblue")
    p2 = plt.bar(categories, cont_tab.iloc[:-1, 1].values, 0.55, bottom=cont_tab.iloc[:-1, 0], color="orange")
    plt.legend((p2[0], p1[0]), ('$y_i=1$', '$y_i=0$'))
    plt.title("Frequency bar chart")
    plt.xlabel(feature)
    plt.xticks(rotation="vertical")
    plt.ylabel("$Frequency$")

    # auxiliary data for 122
    obs_pct = np.array([np.divide(cont_tab.iloc[:-1, 0].values, cont_tab.iloc[:-1, 2].values), 
                        np.divide(cont_tab.iloc[:-1, 1].values, cont_tab.iloc[:-1, 2].values)])
      
    plt.subplot(122)
    p1 = plt.bar(categories, obs_pct[0], 0.55, color="lightblue")
    p2 = plt.bar(categories, obs_pct[1], 0.55, bottom=obs_pct[0], color="orange")
    plt.legend((p2[0], p1[0]), ('$y_i=1$', '$y_i=0$'),labelspacing =1)
    plt.title("Proportion bar chart")
    plt.xlabel(feature)
    plt.ylabel("$p$")
    plt.xticks(rotation="vertical")
    plt.show()

# %% [markdown]
# ### Importing Data

# %% [markdown]
# #### Describe, explore and assess the data

# %%
#To import data from a .csv file to a pandas dataframe
df = pd.read_csv("retail.csv")
df.head(100000)
# Out:
#       InvoiceNo StockCode                          Description  Quantity  \
# 0        536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1        536365     71053                  WHITE METAL LANTERN         6
# 2        536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3        536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4        536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...         ...       ...                                  ...       ...
# 99995    544795     22815              CARD PSYCHEDELIC APPLES        12
# 99996    544795     22028         PENNY FARTHING BIRTHDAY CARD        12
# 99997    544795     22035       VINTAGE CARAVAN GREETING CARD         12
# 99998    544795     22024           RAINY LADIES BIRTHDAY CARD        12
# 99999    544796    85086A          CANDY SPOT HEART DECORATION         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0       12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1       12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2       12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3       12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4       12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...                ...        ...         ...             ...
# 99995  2/23/2011 13:21       0.42     15858.0  United Kingdom
# 99996  2/23/2011 13:21       0.42     15858.0  United Kingdom
# 99997  2/23/2011 13:21       0.42     15858.0  United Kingdom
# 99998  2/23/2011 13:21       0.42     15858.0  United Kingdom
# 99999  2/23/2011 13:37       0.85     16208.0  United Kingdom
#
# [100000 rows x 8 columns]

# %%
#To return a tuple representing the dimensionality of the DataFrame
df.shape
# Out:
# (541909, 8)

# %%
#To return the dtypes in the DataFrame
#In this way, we can start looking better at our data
df.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# Date                period[D]
# MonthYear           period[M]
# dtype: object

# %%
# Summary statistics for all variables
df.describe(include='all').T
# Out:
# C:\Users\scro\AppData\Local\Temp\ipykernel_18136\1271863937.py:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include='all').T
#                 count unique                                 top    freq  \
# InvoiceNo      541909  25900                              573585    1114
# StockCode      541909   4070                              85123A    2313
# Description    540455   4223  WHITE HANGING HEART T-LIGHT HOLDER    2369
# Quantity     541909.0    NaN                                 NaN     NaN
# InvoiceDate    541909  23260                 2011-10-31 14:41:00    1114
# UnitPrice    541909.0    NaN                                 NaN     NaN
# CustomerID   406829.0    NaN                                 NaN     NaN
# Country        541909     38                      United Kingdom  495478
#
#                           first                last         mean          std  \
# InvoiceNo                   NaT                 NaT          NaN          NaN
# StockCode                   NaT                 NaT          NaN          NaN
# Description                 NaT                 NaT          NaN          NaN
# Quantity                    NaT                 NaT      9.55225   218.081158
# InvoiceDate 2010-12-01 08:26:00 2011-12-09 12:50:00          NaN          NaN
# UnitPrice                   NaT                 NaT     4.611114    96.759853
# CustomerID                  NaT                 NaT  15287.69057  1713.600303
# Country                     NaT                 NaT          NaN          NaN
#
#                   min      25%      50%      75%      max
# InvoiceNo         NaN      NaN      NaN      NaN      NaN
# StockCode         NaN      NaN      NaN      NaN      NaN
# Description       NaN      NaN      NaN      NaN      NaN
# Quantity     -80995.0      1.0      3.0     10.0  80995.0
# InvoiceDate       NaN      NaN      NaN      NaN      NaN
# UnitPrice   -11062.06     1.25     2.08     4.13  38970.0
# CustomerID    12346.0  13953.0  15152.0  16791.0  18287.0
# Country           NaN      NaN      NaN      NaN      NaN

# %% [markdown]
# ### Data Engineering

# %%
df["InvoiceDate"] = pd.to_datetime(df["InvoiceDate"])

# %%
df["MonthYear"] = df['InvoiceDate'].dt.to_period('M')

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country        Date  \
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom  2010-12-01
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom  2010-12-01
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom  2010-12-01
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom  2010-12-01
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom  2010-12-01
# ...                    ...        ...         ...             ...         ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France  2011-12-09
# 541905 2011-12-09 12:50:00       2.10     12680.0          France  2011-12-09
# 541906 2011-12-09 12:50:00       4.15     12680.0          France  2011-12-09
# 541907 2011-12-09 12:50:00       4.15     12680.0          France  2011-12-09
# 541908 2011-12-09 12:50:00       4.95     12680.0          France  2011-12-09
#
#        MonthYear
# 0        2010-12
# 1        2010-12
# 2        2010-12
# 3        2010-12
# 4        2010-12
# ...          ...
# 541904   2011-12
# 541905   2011-12
# 541906   2011-12
# 541907   2011-12
# 541908   2011-12
#
# [541909 rows x 10 columns]

# %% [markdown]
# ### Data Exploration

# %%
#Checking for missing data
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df_stockcodes = df.value_counts("StockCode")

# %%
multistockcodes = df_stockcodes[df_stockcodes>1].index.tolist()

# %%
for index in multistockcodes:
    print(index,df[df["StockCode"]==index].value_counts("Description"))
# Out:
# 85123A Description
# WHITE HANGING HEART T-LIGHT HOLDER    2302
# CREAM HANGING HEART T-LIGHT HOLDER       9
# ?                                        1
# wrongly marked carton 22804              1
# dtype: int64
# 22423 Description
# REGENCY CAKESTAND 3 TIER    2200
# damages                        2
# faulty                         1
# dtype: int64
# 85099B Description
# JUMBO BAG RED RETROSPOT    2159
# dtype: int64
# 47566 Description
# PARTY BUNTING    1727
# dtype: int64
# 20725 Description
# LUNCH BAG RED RETROSPOT    1638
# LUNCH BAG RED SPOTTY          1
# dtype: int64
# 84879 Description
# ASSORTED COLOUR BIRD ORNAMENT    1501
# damaged                             1
# dtype: int64
# 22720 Description
# SET OF 3 CAKE TINS PANTRY DESIGN     1473
# dtype: int64
# 22197 Description
# POPCORN HOLDER          865
# SMALL POPCORN HOLDER    611
# dtype: int64
# 21212 Description
# PACK OF 72 RETROSPOT CAKE CASES    1385
# dtype: int64
# 20727 Description
# LUNCH BAG  BLACK SKULL.    1350
# dtype: int64
# 22383 Description
# LUNCH BAG SUKI DESIGN      1139
# LUNCH BAG SUKI  DESIGN      209
# dtype: int64
# 22457 Description
# NATURAL SLATE HEART CHALKBOARD     1280
# dtype: int64
# 23203 Description
# JUMBO BAG VINTAGE DOILY      737
# JUMBO BAG DOILEY PATTERNS    522
# JUMBO BAG VINTAGE DOILEY       7
# mailout                        1
# dtype: int64
# POST Description
# POSTAGE    1252
# dtype: int64
# 22386 Description
# JUMBO BAG PINK POLKADOT    1251
# dtype: int64
# 22469 Description
# HEART OF WICKER SMALL    1237
# dtype: int64
# 22960 Description
# JAM MAKING SET WITH JARS    1229
# dtype: int64
# 21931 Description
# JUMBO STORAGE BAG SUKI    1214
# dtype: int64
# 22086 Description
# PAPER CHAIN KIT 50'S CHRISTMAS     1210
# dtype: int64
# 22411 Description
# JUMBO SHOPPER VINTAGE RED PAISLEY    1202
# dtype: int64
# 20728 Description
# LUNCH BAG CARS BLUE    1197
# dtype: int64
# 22382 Description
# LUNCH BAG SPACEBOY DESIGN     1192
# dtype: int64
# 22961 Description
# JAM MAKING SET PRINTED    1182
# dtype: int64
# 22666 Description
# RECIPE BOX PANTRY YELLOW DESIGN    1180
# dtype: int64
# 23298 Description
# SPOTTY BUNTING       1172
# BUNTING , SPOTTY        7
# dtype: int64
# 22699 Description
# ROSES REGENCY TEACUP AND SAUCER     1138
# dtype: int64
# 22384 Description
# LUNCH BAG PINK POLKADOT    1137
# dtype: int64
# 23209 Description
# LUNCH BAG VINTAGE DOILY      624
# LUNCH BAG DOILEY PATTERN     505
# LUNCH BAG VINTAGE DOILEY       5
# mailout                        1
# dtype: int64
# 82482 Description
# WOODEN PICTURE FRAME WHITE FINISH    1129
# dtype: int64
# 22993 Description
# SET OF 4 PANTRY JELLY MOULDS    1111
# dtype: int64
# 22727 Description
# ALARM CLOCK BAKELIKE RED     1107
# dtype: int64
# 22697 Description
# GREEN REGENCY TEACUP AND SAUCER    1085
# dtype: int64
# 23206 Description
# LUNCH BAG APPLE DESIGN    1084
# dtype: int64
# 22178 Description
# VICTORIAN GLASS HANGING T-LIGHT    1072
# dtype: int64
# 20724 Description
# RED RETROSPOT CHARLOTTE BAG    1068
# dtype: int64
# 23084 Description
# RABBIT NIGHT LIGHT                     1051
# Amazon                                    1
# add stock to allocate online orders       1
# allocate stock for dotcom orders ta       1
# for online retail orders                  1
# temp adjustment                           1
# website fixed                             1
# dtype: int64
# 20726 Description
# LUNCH BAG WOODLAND    1061
# dtype: int64
# 22726 Description
# ALARM CLOCK BAKELIKE GREEN    1024
# dtype: int64
# 21080 Description
# SET/20 RED RETROSPOT PAPER NAPKINS     1015
# dtype: int64
# 23199 Description
# JUMBO BAG APPLES    1009
# dtype: int64
# 22139 Description
# RETROSPOT TEA SET CERAMIC 11 PC     988
# amazon                                1
# dtype: int64
# 22077 Description
# 6 RIBBONS RUSTIC CHARM    986
# dtype: int64
# 22138 Description
# BAKING SET 9 PIECE RETROSPOT     974
# dtype: int64
# 21034 Description
# REX CASH+CARRY JUMBO SHOPPER    967
# dtype: int64
# 22470 Description
# HEART OF WICKER LARGE    961
# dtype: int64
# 85099C Description
# JUMBO  BAG BAROQUE BLACK WHITE    960
# dtype: int64
# 84946 Description
# ANTIQUE SILVER T-LIGHT GLASS       719
# ANTIQUE SILVER TEA GLASS ETCHED    227
# dtype: int64
# 21790 Description
# VINTAGE SNAP CARDS    944
# dtype: int64
# 82494L Description
# WOODEN FRAME ANTIQUE WHITE     938
# cracked                          1
# crushed ctn                      1
# dtype: int64
# 20914 Description
# SET/5 RED RETROSPOT LID GLASS BOWLS    936
# SET/5 RED SPOTTY LID GLASS BOWLS         1
# dtype: int64
# 23301 Description
# GARDENERS KNEELING PAD KEEP CALM     937
# dtype: int64
# 23201 Description
# JUMBO BAG ALPHABET    930
# dtype: int64
# 22629 Description
# SPACEBOY LUNCH BOX     924
# dtype: int64
# 23245 Description
# SET OF 3 REGENCY CAKE TINS    919
# dtype: int64
# 22355 Description
# CHARLOTTE BAG SUKI DESIGN    911
# test                           1
# dtype: int64
# 21232 Description
# STRAWBERRY CERAMIC TRINKET BOX    770
# STRAWBERRY CERAMIC TRINKET POT    134
# dtype: int64
# 23202 Description
# JUMBO BAG VINTAGE LEAF    895
# mailout                     1
# dtype: int64
# 21977 Description
# PACK OF 60 PINK PAISLEY CAKE CASES    896
# dtype: int64
# 22112 Description
# CHOCOLATE HOT WATER BOTTLE    889
# dtype: int64
# 21929 Description
# JUMBO BAG PINK VINTAGE PAISLEY    885
# dtype: int64
# 21181 Description
# PLEASE ONE PERSON METAL SIGN    875
# adjustment                        2
# check                             1
# dotcom                            1
# on cargo order                    1
# dtype: int64
# 22630 Description
# DOLLY GIRL LUNCH BOX    881
# dtype: int64
# 20712 Description
# JUMBO BAG WOODLAND ANIMALS    878
# dtype: int64
# 21731 Description
# RED TOADSTOOL LED NIGHT LIGHT    874
# dtype: int64
# 22722 Description
# SET OF 6 SPICE TINS PANTRY DESIGN    870
# dtype: int64
# 84991 Description
# 60 TEATIME FAIRY CAKE CASES    871
# dtype: int64
# 20719 Description
# WOODLAND CHARLOTTE BAG    858
# dtype: int64
# 22910 Description
# PAPER CHAIN KIT VINTAGE CHRISTMAS    850
# dtype: int64
# 85099F Description
# JUMBO BAG STRAWBERRY    840
# dtype: int64
# 22698 Description
# PINK REGENCY TEACUP AND SAUCER    829
# dtype: int64
# 21175 Description
# GIN + TONIC DIET METAL SIGN      775
# GIN AND TONIC DIET METAL SIGN     50
# dtype: int64
# 21928 Description
# JUMBO BAG SCANDINAVIAN BLUE PAISLEY    675
# JUMBO BAG SCANDINAVIAN PAISLEY         148
# dtype: int64
# 23355 Description
# HOT WATER BOTTLE KEEP CALM    813
# dtype: int64
# 22090 Description
# PAPER BUNTING RETROSPOT    812
# dtype: int64
# 22728 Description
# ALARM CLOCK BAKELIKE PINK    810
# dtype: int64
# 21754 Description
# HOME BUILDING BLOCK WORD    806
# dtype: int64
# 22111 Description
# SCOTTIE DOG HOT WATER BOTTLE    798
# dtype: int64
# 22558 Description
# CLOTHES PEGS RETROSPOT PACK 24     792
# dtype: int64
# 23300 Description
# GARDENERS KNEELING PAD CUP OF TEA     780
# dtype: int64
# 23207 Description
# LUNCH BAG ALPHABET DESIGN    780
# dtype: int64
# 22356 Description
# CHARLOTTE BAG PINK POLKADOT    777
# dtype: int64
# 21733 Description
# RED HANGING HEART T-LIGHT HOLDER    773
# dtype: int64
# 84978 Description
# HANGING HEART JAR T-LIGHT HOLDER    767
# dtype: int64
# 22326 Description
# ROUND SNACK BOXES SET OF4 WOODLAND     764
# dtype: int64
# 22379 Description
# RECYCLING BAG RETROSPOT     760
# dtype: int64
# 22659 Description
# LUNCH BOX I LOVE LONDON    750
# dtype: int64
# 23284 Description
# DOORMAT KEEP CALM AND COME IN    742
# dtype: int64
# 21166 Description
# COOK WITH WINE METAL SIGN     745
# ?                               1
# dtype: int64
# 20723 Description
# STRAWBERRY CHARLOTTE BAG    742
# dtype: int64
# 22624 Description
# IVORY KITCHEN SCALES    741
# dtype: int64
# 23344 Description
# JUMBO BAG 50'S CHRISTMAS     739
# dtype: int64
# 22467 Description
# GUMBALL COAT RACK               728
# wrong code?                       1
# wrongly sold (22719) barcode      1
# dtype: int64
# 22554 Description
# PLASTERS IN TIN WOODLAND ANIMALS    729
# dtype: int64
# 21930 Description
# JUMBO STORAGE BAG SKULLS    720
# dtype: int64
# DOT Description
# DOTCOM POSTAGE    709
# dtype: int64
# 22907 Description
# PACK OF 20 NAPKINS PANTRY DESIGN    709
# dtype: int64
# 84380 Description
# SET OF 3 BUTTERFLY COOKIE CUTTERS    707
# dtype: int64
# 20685 Description
# DOORMAT RED RETROSPOT    707
# dtype: int64
# 22662 Description
# LUNCH BAG DOLLY GIRL DESIGN    706
# dtype: int64
# 22385 Description
# JUMBO BAG SPACEBOY DESIGN    702
# dtype: int64
# 84378 Description
# SET OF 3 HEART COOKIE CUTTERS    700
# dtype: int64
# 82484 Description
# WOOD BLACK BOARD ANT WHITE FINISH    698
# dtype: int64
# 22551 Description
# PLASTERS IN TIN SPACEBOY    697
# dtype: int64
# 22966 Description
# GINGERBREAD MAN COOKIE CUTTER    691
# dtype: int64
# 23208 Description
# LUNCH BAG VINTAGE LEAF DESIGN    692
# dtype: int64
# 22865 Description
# HAND WARMER OWL DESIGN    687
# dtype: int64
# 85152 Description
# HAND OVER THE CHOCOLATE   SIGN     686
# dtype: int64
# 20713 Description
# JUMBO BAG OWLS                  673
# Found                             1
# Marked as 23343                   1
# found                             1
# wrongly coded 23343               1
# wrongly coded-23343               1
# wrongly marked 23343              1
# wrongly marked. 23343 in box      1
# dtype: int64
# 79321 Description
# CHILLI LIGHTS    679
# dtype: int64
# 22835 Description
# HOT WATER BOTTLE I AM SO POORLY    679
# dtype: int64
# 21213 Description
# PACK OF 72 SKULL CAKE CASES    678
# dtype: int64
# 21915 Description
# RED  HARMONICA IN BOX     676
# John Lewis                  1
# dtype: int64
# 22114 Description
# HOT WATER BOTTLE TEA AND SYMPATHY    656
# dtype: int64
# 23307 Description
# SET OF 60 PANTRY DESIGN CAKE CASES     659
# dtype: int64
# 23321 Description
# SMALL WHITE HEART OF WICKER    657
# dtype: int64
# 21755 Description
# LOVE BUILDING BLOCK WORD    656
# dtype: int64
# 21485 Description
# RETROSPOT HEART HOT WATER BOTTLE    655
# dtype: int64
# 22969 Description
# HOMEMADE JAM SCENTED CANDLES    655
# dtype: int64
# 22952 Description
# 60 CAKE CASES VINTAGE CHRISTMAS    652
# 72 CAKE CASES VINTAGE CHRISTMAS      1
# dtype: int64
# 82583 Description
# HOT BATHS METAL SIGN    643
# amazon                    2
# ?                         1
# FBA                       1
# dtype: int64
# 84992 Description
# 72 SWEETHEART FAIRY CAKE CASES    650
# dtype: int64
# 21975 Description
# PACK OF 60 DINOSAUR CAKE CASES    641
# dtype: int64
# 82580 Description
# BATHROOM METAL SIGN    641
# dtype: int64
# 22909 Description
# SET OF 20 VINTAGE CHRISTMAS NAPKINS    640
# dtype: int64
# 84755 Description
# COLOUR GLASS T-LIGHT HOLDER HANGING    640
# dtype: int64
# 82486 Description
# WOOD S/3 CABINET ANT WHITE FINISH      424
# 3 DRAWER ANTIQUE WHITE WOOD CABINET    213
# dtype: int64
# 20972 Description
# PINK CREAM FELT CRAFT TRINKET BOX     633
# dtype: int64
# 48138 Description
# DOORMAT UNION FLAG    627
# dtype: int64
# 22621 Description
# TRADITIONAL KNITTING NANCY    625
# dtype: int64
# 22083 Description
# PAPER CHAIN KIT RETROSPOT    619
# dtype: int64
# 21791 Description
# VINTAGE HEADS AND TAILS CARD GAME     617
# dtype: int64
# 21914 Description
# BLUE HARMONICA IN BOX     615
# dtype: int64
# 22328 Description
# ROUND SNACK BOXES SET OF 4 FRUITS     611
# dtype: int64
# 23200 Description
# JUMBO BAG PEARS    608
# mailout              1
# dtype: int64
# 48187 Description
# DOORMAT NEW ENGLAND    608
# dtype: int64
# 21889 Description
# WOODEN BOX OF DOMINOES    607
# dtype: int64
# 84692 Description
# BOX OF 24 COCKTAIL PARASOLS    603
# dtype: int64
# 82483 Description
# WOOD 2 DRAWER CABINET WHITE FINISH    600
# crushed                                 1
# dtype: int64
# 48194 Description
# DOORMAT HEARTS    599
# dtype: int64
# 21559 Description
# STRAWBERRY LUNCH BOX WITH CUTLERY    598
# dtype: int64
# 22113 Description
# GREY HEART HOT WATER BOTTLE    595
# dtype: int64
# 22730 Description
# ALARM CLOCK BAKELIKE IVORY    594
# dtype: int64
# 23204 Description
# CHARLOTTE BAG APPLES DESIGN    594
# dtype: int64
# 23322 Description
# LARGE WHITE HEART OF WICKER    593
# mouldy                           1
# dtype: int64
# 22553 Description
# PLASTERS IN TIN SKULLS    593
# dtype: int64
# 22556 Description
# PLASTERS IN TIN CIRCUS PARADE     591
# dtype: int64
# 22866 Description
# HAND WARMER SCOTTY DOG DESIGN    585
# dtype: int64
# 22557 Description
# PLASTERS IN TIN VINTAGE PAISLEY     589
# dtype: int64
# 20718 Description
# RED RETROSPOT SHOPPER BAG    586
# dtype: int64
# 21843 Description
# RED RETROSPOT CAKE STAND    584
# smashed                       1
# dtype: int64
# 21314 Description
# SMALL GLASS HEART TRINKET POT    585
# dtype: int64
# 22776 Description
# SWEETHEART CAKESTAND 3 TIER      407
# SWEETHEART 3 TIER CAKE STAND     170
# CAKESTAND, 3 TIER, LOVEHEART       1
# dtype: int64
# 22625 Description
# RED KITCHEN SCALES    577
# dtype: int64
# 22867 Description
# HAND WARMER BIRD DESIGN    574
# dtype: int64
# 22367 Description
# CHILDRENS APRON SPACEBOY DESIGN    573
# dtype: int64
# 22149 Description
# FELTCRAFT 6 FLOWER FRIENDS    568
# check                           2
# damages                         1
# dtype: int64
# M Description
# Manual    571
# dtype: int64
# 23293 Description
# SET OF 12 FAIRY CAKE BAKING CASES    567
# dtype: int64
# 23240 Description
# SET OF 4 KNICK KNACK TINS DOILY       373
# SET OF 4 KNICK KNACK TINS DOILEY      193
# SET OF 4 KNICK KNACK TINS  DOILEY       1
# dtype: int64
# 22900 Description
#  SET 2 TEA TOWELS I LOVE LONDON     282
# SET 2 TEA TOWELS I LOVE LONDON      282
# dtype: int64
# 22144 Description
# CHRISTMAS CRAFT LITTLE FRIENDS    563
# dtype: int64
# 22219 Description
# LOVEBIRD HANGING DECORATION WHITE     560
# ???lost                                 1
# dtype: int64
# 22577 Description
# WOODEN HEART CHRISTMAS SCANDINAVIAN    557
# check                                    1
# dtype: int64
# 22998 Description
# TRAVEL CARD WALLET KEEP CALM    557
# dtype: int64
# 82600 Description
# NO SINGING METAL SIGN                  505
# N0 SINGING METAL SIGN                   49
# check                                    1
# historic computer difference?....se      1
# dtype: int64
# 85066 Description
# CREAM SWEETHEART MINI CHEST    555
# dtype: int64
# 84836 Description
# ZINC METAL HEART DECORATION    552
# dtype: int64
# 21174 Description
# POTTERING IN THE SHED METAL SIGN    547
# found                                 1
# dtype: int64
# 84970S Description
# HANGING HEART ZINC T-LIGHT HOLDER    546
# dtype: int64
# 21936 Description
# RED RETROSPOT PICNIC BAG    546
# dtype: int64
# 21231 Description
# SWEETHEART CERAMIC TRINKET BOX    543
# dtype: int64
# 84077 Description
# WORLD WAR 2 GLIDERS ASSTD DESIGNS    542
# dtype: int64
# 84596B Description
# SMALL DOLLY MIX DESIGN ORANGE BOWL    541
# dtype: int64
# 20971 Description
# PINK BLUE FELT CRAFT TRINKET BOX    538
# dtype: int64
# 22578 Description
# WOODEN STAR CHRISTMAS SCANDINAVIAN    535
# lost                                    1
# dtype: int64
# 22189 Description
# CREAM HEART CARD HOLDER    536
# dtype: int64
# 22417 Description
# PACK OF 60 SPACEBOY CAKE CASES    535
# dtype: int64
# 20711 Description
# JUMBO BAG TOYS     532
# check                1
# lost in space        1
# dtype: int64
# 22555 Description
# PLASTERS IN TIN STRONGMAN    534
# dtype: int64
# 84375 Description
# SET OF 20 KIDS COOKIE CUTTERS    533
# dtype: int64
# 22766 Description
# PHOTO FRAME CORNICE    533
# dtype: int64
# 21094 Description
# SET/6 RED SPOTTY PAPER PLATES    532
# dtype: int64
# 21935 Description
# SUKI  SHOULDER BAG    532
# dtype: int64
# 22029 Description
# SPACEBOY BIRTHDAY CARD    531
# dtype: int64
# 22616 Description
# PACK OF 12 LONDON TISSUES     531
# dtype: int64
# 22427 Description
# ENAMEL FLOWER JUG CREAM    528
# damages                      1
# dtype: int64
# 15036 Description
# ASSORTED COLOURS SILK FAN    523
# dtype: int64
# 21479 Description
# WHITE SKULL HOT WATER BOTTLE     518
# ?                                  1
# dtype: int64
# 22633 Description
# HAND WARMER UNION JACK    515
# dtype: int64
# 84988 Description
# SET OF 72 PINK HEART PAPER DOILIES    514
# ?                                       1
# dtype: int64
# 21481 Description
# FAWN BLUE HOT WATER BOTTLE    513
# dtype: int64
# 22456 Description
# NATURAL SLATE CHALKBOARD LARGE     511
# dtype: int64
# 23243 Description
# SET OF TEA COFFEE SUGAR TINS PANTRY    509
# dtype: int64
# 22173 Description
# METAL 4 HOOK HANGER FRENCH CHATEAU    506
# dtype: int64
# 22147 Description
# FELTCRAFT BUTTERFLY HEARTS    506
# check                           1
# dtype: int64
# 21523 Description
# DOORMAT FANCY FONT HOME SWEET HOME    506
# dtype: int64
# 21155 Description
# RED RETROSPOT PEG BAG    506
# dtype: int64
# 23198 Description
# PANTRY MAGNETIC  SHOPPING LIST    503
# dtype: int64
# 23356 Description
# LOVE HOT WATER BOTTLE    502
# dtype: int64
# 23343 Description
# JUMBO BAG VINTAGE CHRISTMAS     496
# wrongly coded 20713               2
# 20713                             1
# 20713 wrongly marked              1
# came coded as 20713               1
# dtype: int64
# 22667 Description
# RECIPE BOX RETROSPOT     499
# damaged                    1
# dtype: int64
# 22352 Description
# LUNCH BOX WITH CUTLERY RETROSPOT     498
# dtype: int64
# 22620 Description
# 4 TRADITIONAL SPINNING TOPS    498
# dtype: int64
# 22804 Description
# CANDLEHOLDER PINK HANGING HEART      416
# PINK HANGING HEART T-LIGHT HOLDER     79
# Wrongly mrked had 85123a in box        1
# dtype: int64
# 21621 Description
# VINTAGE UNION JACK BUNTING             491
# ?                                        1
# rcvd be air temp fix for dotcom sit      1
# re dotcom quick fix.                     1
# dtype: int64
# 21430 Description
# SET/3 RED GINGHAM ROSE STORAGE BOX    494
# dtype: int64
# 23263 Description
# SET OF 3 WOODEN HEART DECORATIONS    492
# dtype: int64
# 22568 Description
# FELTCRAFT CUSHION OWL    488
# ?? missing                 1
# dtype: int64
# 22196 Description
# SMALL HEART MEASURING SPOONS    489
# dtype: int64
# 21524 Description
# DOORMAT SPOTTY HOME SWEET HOME    489
# dtype: int64
# 85150 Description
# LADIES & GENTLEMEN METAL SIGN    485
# dtype: int64
# 22502 Description
# PICNIC BASKET WICKER SMALL        477
# PICNIC BASKET WICKER 60 PIECES      2
# reverse 21/5/10 adjustment          1
# dtype: int64
# 21172 Description
# PARTY METAL SIGN     482
# dtype: int64
# 22617 Description
# BAKING SET SPACEBOY DESIGN    483
# mouldy, thrown away.            1
# dtype: int64
# 22150 Description
# 3 STRIPEY MICE FELTCRAFT    483
# dtype: int64
# 22381 Description
# TOY TIDY PINK POLKADOT    482
# dtype: int64
# 84997D Description
# CHILDRENS CUTLERY POLKADOT PINK      364
# PINK 3 PIECE POLKADOT CUTLERY SET    117
# dtype: int64
# 23205 Description
# CHARLOTTE BAG VINTAGE ALPHABET     458
# CHARLOTTE BAG ALPHABET  DESIGN      22
# dtype: int64
# 22652 Description
# TRAVEL SEWING KIT    478
# check                  1
# dtype: int64
# 21908 Description
# CHOCOLATE THIS WAY METAL SIGN    478
# dtype: int64
# 22595 Description
# GINGHAM HEART DECORATION    422
# CHRISTMAS GINGHAM HEART      55
# check                         1
# dtype: int64
# 35970 Description
# ZINC FOLKART SLEIGH BELLS    476
# dtype: int64
# 84347 Description
# ROTATING SILVER ANGELS T-LIGHT HLDR    475
# dtype: int64
# 22501 Description
# PICNIC BASKET WICKER LARGE         466
# Found                                1
# incorrectly put back into stock      1
# reverse 21/5/10 adjustment           1
# dtype: int64
# 84029G Description
# KNITTED UNION FLAG HOT WATER BOTTLE    473
# dtype: int64
# 22729 Description
# ALARM CLOCK BAKELIKE ORANGE    473
# dtype: int64
# 22141 Description
# CHRISTMAS CRAFT TREE TOP ANGEL    473
# dtype: int64
# 22424 Description
# ENAMEL BREAD BIN CREAM    473
# dtype: int64
# 22193 Description
# RED DINER WALL CLOCK    472
# dtype: int64
# 21169 Description
# YOU'RE CONFUSING ME METAL SIGN     469
# dtype: int64
# 22749 Description
# FELTCRAFT PRINCESS CHARLOTTE DOLL    469
# dtype: int64
# 15056N Description
# EDWARDIAN PARASOL NATURAL    467
# dtype: int64
# 22507 Description
# MEMO BOARD RETROSPOT  DESIGN    464
# dtype: int64
# 21210 Description
# SET OF 72 RETROSPOT PAPER  DOILIES    462
# dtype: int64
# 21154 Description
# RED RETROSPOT OVEN GLOVE     463
# dtype: int64
# 84970L Description
# SINGLE HEART ZINC T-LIGHT HOLDER    460
# dtype: int64
# 21165 Description
# BEWARE OF THE CAT METAL SIGN     458
# check                              1
# dtype: int64
# 23295 Description
# SET OF 12 MINI LOAF BAKING CASES    460
# dtype: int64
# 20676 Description
# RED RETROSPOT BOWL    459
# dtype: int64
# 21668 Description
# RED STRIPE CERAMIC DRAWER KNOB    458
# dtype: int64
# 22771 Description
# CLEAR DRAWER KNOB ACRYLIC EDWARDIAN    458
# dtype: int64
# 23170 Description
# REGENCY TEA PLATE ROSES     458
# dtype: int64
# 22951 Description
# 60 CAKE CASES DOLLY GIRL DESIGN    458
# dtype: int64
# 21932 Description
# SCANDINAVIAN PAISLEY PICNIC BAG    457
# dtype: int64
# 22084 Description
# PAPER CHAIN KIT EMPIRE    448
# dtype: int64
# 22619 Description
# SET OF 6 SOLDIER SKITTLES    455
# dtype: int64
# 22663 Description
# JUMBO BAG DOLLY GIRL DESIGN    454
# dtype: int64
# 21992 Description
# VINTAGE PAISLEY STATIONERY SET    453
# check                               1
# dtype: int64
# 22725 Description
# ALARM CLOCK BAKELIKE CHOCOLATE    453
# dtype: int64
# 21891 Description
# TRADITIONAL WOODEN SKIPPING ROPE    451
# dtype: int64
# 23182 Description
# TOILET SIGN OCCUPIED OR VACANT    452
# dtype: int64
# 22692 Description
# DOORMAT WELCOME TO OUR HOME    452
# dtype: int64
# 71459 Description
# HANGING JAM JAR T-LIGHT HOLDER     359
# HANGING JAM JAR T-LIGHT HOLDERS     93
# dtype: int64
# 84596F Description
# SMALL MARSHMALLOWS PINK BOWL    452
# dtype: int64
# 84029E Description
# RED WOOLLY HOTTIE WHITE HEART.    449
# dtype: int64
# 21669 Description
# BLUE STRIPE CERAMIC DRAWER KNOB    451
# dtype: int64
# 22748 Description
# POPPY'S PLAYHOUSE KITCHEN    451
# dtype: int64
# 22489 Description
# PACK OF 12 TRADITIONAL CRAYONS    450
# dtype: int64
# 21216 Description
# SET 3 RETROSPOT TEA,COFFEE,SUGAR    449
# dtype: int64
# 22561 Description
# WOODEN SCHOOL COLOURING SET    449
# dtype: int64
# 22983 Description
# CARD BILLBOARD FONT    447
# dtype: int64
# 22487 Description
# WHITE WOOD GARDEN PLANT LADDER    447
# dtype: int64
# 22734 Description
# SET OF 6 RIBBONS VINTAGE CHRISTMAS    440
# amazon                                  3
# FOUND                                   1
# amazon sales                            1
# dtype: int64
# 82582 Description
# AREA PATROLLED METAL SIGN    445
# ??                             1
# dtype: int64
# 47591D Description
# PINK FAIRY CAKE CHILDRENS APRON    445
# dtype: int64
# 22759 Description
# SET OF 3 NOTEBOOKS IN PARCEL    441
# check                             2
# found                             1
# dtype: int64
# 22988 Description
# SOLDIERS EGG CUP     439
# dtype: int64
# 22191 Description
# IVORY DINER WALL CLOCK    441
# dtype: int64
# 21086 Description
# SET/6 RED SPOTTY PAPER CUPS    439
# dtype: int64
# 23173 Description
# REGENCY TEAPOT ROSES     438
# dtype: int64
# 22745 Description
# POPPY'S PLAYHOUSE BEDROOM     436
# dtype: int64
# 23309 Description
# SET OF 60 I LOVE LONDON CAKE CASES     435
# dtype: int64
# 21985 Description
# PACK OF 12 HEARTS DESIGN TISSUES     434
# dtype: int64
# 21993 Description
# FLORAL FOLK STATIONERY SET    433
# dtype: int64
# 23493 Description
# VINTAGE DOILY TRAVEL SEWING KIT    433
# dtype: int64
# 22082 Description
# RIBBON REEL STRIPES DESIGN     429
# dtype: int64
# 22844 Description
# VINTAGE CREAM DOG FOOD CONTAINER    429
# dtype: int64
# 22750 Description
# FELTCRAFT PRINCESS LOLA DOLL    428
# dtype: int64
# 22488 Description
# NATURAL SLATE RECTANGLE CHALKBOARD    427
# dtype: int64
# 21558 Description
# SKULL LUNCH BOX WITH CUTLERY     427
# dtype: int64
# 21672 Description
# WHITE SPOT RED CERAMIC DRAWER KNOB    426
# dtype: int64
# 22661 Description
# CHARLOTTE BAG DOLLY GIRL DESIGN    425
# dtype: int64
# 23439 Description
# HAND WARMER RED LOVE HEART    425
# dtype: int64
# 21933 Description
# PINK VINTAGE PAISLEY PICNIC BAG    425
# dtype: int64
# 23319 Description
# BOX OF 6 MINI 50'S CRACKERS    425
# dtype: int64
# 21892 Description
# TRADITIONAL WOODEN CATCH CUP GAME     424
# dtype: int64
# 85049E Description
# SCANDINAVIAN REDS RIBBONS    423
# dtype: int64
# 21484 Description
# CHICK GREY HOT WATER BOTTLE    422
# dtype: int64
# 22996 Description
# TRAVEL CARD WALLET VINTAGE TICKET    422
# dtype: int64
# 22413 Description
# METAL SIGN TAKE IT OR LEAVE IT     422
# dtype: int64
# 22585 Description
# PACK OF 6 BIRDY GIFT TAGS    420
# dtype: int64
# 20717 Description
# STRAWBERRY SHOPPER BAG    420
# dtype: int64
# 22694 Description
# WICKER STAR     419
# dtype: int64
# 22212 Description
# FOUR HOOK  WHITE LOVEBIRDS    418
# dtype: int64
# 23328 Description
# SET 6 SCHOOL MILK BOTTLES IN CRATE    418
# dtype: int64
# 48184 Description
# DOORMAT ENGLISH ROSE     416
# dtype: int64
# 23313 Description
# VINTAGE CHRISTMAS BUNTING    415
# dtype: int64
# 22632 Description
# HAND WARMER RED RETROSPOT    395
# HAND WARMER RED POLKA DOT     18
# dtype: int64
# 22371 Description
# AIRLINE BAG VINTAGE TOKYO 78    413
# dtype: int64
# 21934 Description
# SKULL SHOULDER BAG    413
# dtype: int64
# 22499 Description
# WOODEN UNION JACK BUNTING    412
# dtype: int64
# 82581 Description
# TOILET METAL SIGN    411
# dtype: int64
# 22631 Description
# CIRCUS PARADE LUNCH BOX     411
# dtype: int64
# 22847 Description
# BREAD BIN DINER STYLE IVORY      406
# BREAD BIN, DINER STYLE, IVORY      1
# dtype: int64
# 21218 Description
# RED SPOTTY BISCUIT TIN    409
# dtype: int64
# 21976 Description
# PACK OF 60 MUSHROOM CAKE CASES    408
# dtype: int64
# 22171 Description
# 3 HOOK PHOTO SHELF ANTIQUE WHITE    403
# ?                                     1
# dtype: int64
# 22646 Description
# CERAMIC STRAWBERRY CAKE MONEY BANK    406
# dtype: int64
# 22570 Description
# FELTCRAFT CUSHION RABBIT    398
# ?                             1
# dtype: int64
# 22429 Description
# ENAMEL MEASURING JUG CREAM    403
# dtype: int64
# 21035 Description
# SET/2 RED RETROSPOT TEA TOWELS     403
# dtype: int64
# 47590B Description
# PINK HAPPY BIRTHDAY BUNTING    401
# check                            1
# dtype: int64
# 21912 Description
# VINTAGE SNAKES & LADDERS    401
# dtype: int64
# 21238 Description
# RED RETROSPOT CUP    400
# dtype: int64
# 22979 Description
# PANTRY WASHING UP BRUSH    395
# dtype: int64
# 47590A Description
# BLUE HAPPY BIRTHDAY BUNTING    394
# dtype: int64
# 23308 Description
# SET OF 60 VINTAGE LEAF CAKE CASES     394
# dtype: int64
# 20749 Description
# ASSORTED COLOUR MINI CASES    394
# dtype: int64
# 23108 Description
# SET OF 10 LED DOLLY LIGHTS    393
# dtype: int64
# 22142 Description
# CHRISTMAS CRAFT WHITE FAIRY     391
# check                             2
# dtype: int64
# 21121 Description
# SET/10 RED POLKADOT PARTY CANDLES    392
# dtype: int64
# 21770 Description
# OPEN CLOSED METAL SIGN    392
# dtype: int64
# 22560 Description
# TRADITIONAL MODELLING CLAY    391
# dtype: int64
# 22964 Description
# 3 PIECE SPACEBOY COOKIE CUTTER SET    391
# dtype: int64
# 23318 Description
# BOX OF 6 MINI VINTAGE CRACKERS    391
# dtype: int64
# 20750 Description
# RED RETROSPOT MINI CASES    391
# dtype: int64
# 22169 Description
# FAMILY ALBUM WHITE PICTURE FRAME    390
# dtype: int64
# 22492 Description
# MINI PAINT SET VINTAGE     390
# dtype: int64
# 21670 Description
# BLUE SPOT CERAMIC DRAWER KNOB    389
# dtype: int64
# 21888 Description
# BINGO SET    387
# Amazon         1
# check          1
# dtype: int64
# 22752 Description
# SET 7 BABUSHKA NESTING BOXES    389
# dtype: int64
# 22908 Description
# PACK OF 20 NAPKINS RED APPLES    389
# dtype: int64
# 22297 Description
# HEART IVORY TRELLIS SMALL    389
# dtype: int64
# 23296 Description
# SET OF 6 TEA TIME BAKING CASES    389
# dtype: int64
# 23171 Description
# REGENCY TEA PLATE GREEN     388
# dtype: int64
# 21671 Description
# RED SPOT CERAMIC DRAWER KNOB    388
# dtype: int64
# 22834 Description
# HAND WARMER BABUSHKA DESIGN    386
# dtype: int64
# 23103 Description
# JINGLE BELL HEART DECORATION    377
# BELL HEART DECORATION             9
# dtype: int64
# 21673 Description
# WHITE SPOT BLUE CERAMIC DRAWER KNOB    384
# dtype: int64
# 21137 Description
# BLACK RECORD COVER FRAME    384
# dtype: int64
# 21136 Description
# PAINTED METAL PEARS ASSORTED    382
# sold as set on dotcom             1
# dtype: int64
# 22989 Description
# SET 2 PANTRY DESIGN TEA TOWELS    383
# dtype: int64
# 22195 Description
# LARGE HEART MEASURING SPOONS    382
# dtype: int64
# 22627 Description
# MINT KITCHEN SCALES    379
# dtype: int64
# 23256 Description
# CHILDRENS CUTLERY SPACEBOY     374
# KIDS CUTLERY SPACEBOY            8
# dtype: int64
# 21900 Description
# KEY FOB , SHED    380
# dtype: int64
# 23241 Description
# TREASURE TIN GYMKHANA DESIGN    379
# dtype: int64
# 47566B Description
# TEA TIME PARTY BUNTING                 376
# incorrectly credited C550456 see 47      2
# reverse previous adjustment              1
# dtype: int64
# 21918 Description
# SET 12 KIDS COLOUR  CHALK STICKS    376
# dtype: int64
# 20975 Description
# 12 PENCILS SMALL TUBE RED RETROSPOT    374
# dtype: int64
# 84997B Description
# CHILDRENS CUTLERY RETROSPOT RED      266
# RED 3 PIECE RETROSPOT CUTLERY SET    111
# dtype: int64
# 21990 Description
# MODERN FLORAL STATIONERY SET    376
# dtype: int64
# 22795 Description
# SWEETHEART RECIPE BOOK STAND    375
# dtype: int64
# 20973 Description
# 12 PENCIL SMALL TUBE WOODLAND    372
# dtype: int64
# 21871 Description
# SAVE THE PLANET MUG    374
# dtype: int64
# 22192 Description
# BLUE DINER WALL CLOCK    372
# dtype: int64
# 21907 Description
# I'M ON HOLIDAY METAL SIGN    372
# dtype: int64
# 22898 Description
# CHILDRENS APRON APPLES DESIGN    372
# dtype: int64
# 21982 Description
# PACK OF 12 SUKI TISSUES     372
# dtype: int64
# 22665 Description
# RECIPE BOX BLUE SKETCHBOOK DESIGN    371
# dtype: int64
# 48185 Description
# DOORMAT FAIRY CAKE    371
# ?                       1
# dtype: int64
# 84945 Description
# MULTI COLOUR SILVER T-LIGHT HOLDER    372
# dtype: int64
# 82552 Description
# WASHROOM METAL SIGN    371
# dtype: int64
# 22464 Description
# HANGING METAL HEART LANTERN    371
# dtype: int64
# 84947 Description
# ANTIQUE SILVER TEA GLASS ENGRAVED    371
# dtype: int64
# 21877 Description
# HOME SWEET HOME MUG    370
# dtype: int64
# 20974 Description
# 12 PENCILS SMALL TUBE SKULL    370
# dtype: int64
# 21535 Description
# RED RETROSPOT SMALL MILK JUG    369
# dtype: int64
# 22041 Description
# RECORD FRAME 7" SINGLE SIZE     369
# dtype: int64
# 21156 Description
# RETROSPOT CHILDRENS APRON    369
# dtype: int64
# 22027 Description
# TEA PARTY BIRTHDAY CARD    369
# dtype: int64
# 23294 Description
# SET OF 6 SNACK LOAF BAKING CASES    369
# dtype: int64
# 21974 Description
# SET OF 36 PAISLEY FLOWER DOILIES    366
# dtype: int64
# 21916 Description
# SET 12 RETRO WHITE CHALK STICKS    367
# dtype: int64
# 22992 Description
# REVOLVER WOODEN RULER     367
# dtype: int64
# 22962 Description
# JAM JAR WITH PINK LID    366
# dtype: int64
# 22607 Description
# WOODEN ROUNDERS GARDEN SET     366
# dtype: int64
# 22348 Description
# TEA BAG PLATE RED RETROSPOT    364
# dtype: int64
# 23351 Description
# ROLL WRAP 50'S CHRISTMAS    364
# dtype: int64
# 22549 Description
# PICTURE DOMINOES    363
# dtype: int64
# 22645 Description
# CERAMIC HEART FAIRY CAKE MONEY BANK    363
# dtype: int64
# 22161 Description
# HEART DECORATION RUSTIC HANGING     363
# dtype: int64
# 22851 Description
# SET 20 NAPKINS FAIRY CAKES DESIGN     363
# dtype: int64
# 22791 Description
# T-LIGHT GLASS FLUTED ANTIQUE    361
# dtype: int64
# 21533 Description
# RETROSPOT LARGE MILK JUG    361
# dtype: int64
# 23168 Description
# CLASSIC CAFE SUGAR DISPENSER    349
# CLASSIC SUGAR DISPENSER          12
# dtype: int64
# 22569 Description
# FELTCRAFT CUSHION BUTTERFLY    358
# ?                                1
# dtype: int64
# 22037 Description
# ROBOT BIRTHDAY CARD    359
# dtype: int64
# 23192 Description
# BUNDLE OF 3 ALPHABET EXERCISE BOOKS    359
# dtype: int64
# 21122 Description
# SET/10 PINK POLKADOT PARTY CANDLES    358
# dtype: int64
# 22637 Description
# PIGGY BANK RETROSPOT     357
# damages                    1
# dtype: int64
# 82551 Description
# LAUNDRY 15C METAL SIGN    356
# dtype: int64
# 23236 Description
# STORAGE TIN VINTAGE DOILY      213
# DOILEY STORAGE TIN             128
# DOILEY BISCUIT TIN              13
# STORAGE TIN VINTAGE DOILEY       2
# dtype: int64
# 71477 Description
# COLOUR GLASS. STAR T-LIGHT HOLDER     291
# COLOURED GLASS STAR T-LIGHT HOLDER     61
# dtype: int64
# 71053 Description
# WHITE METAL LANTERN             328
# WHITE MOROCCAN METAL LANTERN     27
# dtype: int64
# 21326 Description
# AGED GLASS SILVER T-LIGHT HOLDER    355
# dtype: int64
# 22579 Description
# WOODEN TREE CHRISTMAS SCANDINAVIAN    351
# dotcom                                  1
# dtype: int64
# 23581 Description
# JUMBO BAG PAISLEY PARK    355
# dtype: int64
# 85014B Description
# RED RETROSPOT UMBRELLA    355
# dtype: int64
# 23169 Description
# CLASSIC GLASS COOKIE JAR    338
# CLASSIC GLASS SWEET JAR      14
# smashed                       1
# dtype: int64
# 21328 Description
# BALLOONS  WRITING SET     353
# dtype: int64
# 21217 Description
# RED RETROSPOT ROUND CAKE TINS    352
# dtype: int64
# 23311 Description
# VINTAGE CHRISTMAS STOCKING     351
# dtype: int64
# 22668 Description
# PINK BABY BUNTING    351
# dtype: int64
# 23349 Description
# ROLL WRAP VINTAGE CHRISTMAS    350
# dtype: int64
# 23077 Description
# DOUGHNUT LIP GLOSS     348
# dtype: int64
# 23503 Description
# PLAYING CARDS KEEP CALM & CARRY ON    347
# dtype: int64
# 23320 Description
# GIANT 50'S CHRISTMAS CRACKER    346
# dtype: int64
# 84030E Description
# ENGLISH ROSE HOT WATER BOTTLE    346
# dtype: int64
# 22087 Description
# PAPER BUNTING WHITE LACE    342
# Amazon                        1
# dtype: int64
# 84536A Description
# ENGLISH ROSE NOTEBOOK A7 SIZE    346
# dtype: int64
# 23175 Description
# REGENCY MILK JUG PINK     343
# dtype: int64
# 21876 Description
# POTTERING MUG    345
# dtype: int64
# 20979 Description
# 36 PENCILS TUBE RED RETROSPOT    345
# dtype: int64
# 22654 Description
# DELUXE SEWING KIT     345
# dtype: int64
# 22151 Description
# PLACE SETTING WHITE HEART    345
# dtype: int64
# 23275 Description
# SET OF 3 HANGING OWLS OLLIE BEAK    345
# dtype: int64
# 22273 Description
# FELTCRAFT DOLL MOLLY    344
# dtype: int64
# 85053 Description
# FRENCH ENAMEL CANDLEHOLDER    344
# dtype: int64
# 23266 Description
# SET OF 3 WOODEN STOCKING DECORATION    343
# dtype: int64
# 22431 Description
# WATERING CAN BLUE ELEPHANT    343
# dtype: int64
# 23188 Description
# VINTAGE  2 METER FOLDING RULER    186
# VINTAGE  2 METRE FOLDING RULER    156
# dtype: int64
# 21989 Description
# PACK OF 20 SKULL PAPER NAPKINS    342
# dtype: int64
# 23174 Description
# REGENCY SUGAR BOWL GREEN    342
# dtype: int64
# 20677 Description
# PINK POLKADOT BOWL    340
# dtype: int64
# 84997C Description
# CHILDRENS CUTLERY POLKADOT BLUE      236
# BLUE 3 PIECE POLKADOT CUTLERY SET    102
# ?                                      1
# dtype: int64
# 84987 Description
# SET OF 36 TEATIME PAPER DOILIES    339
# dtype: int64
# 22940 Description
# FELTCRAFT CHRISTMAS FAIRY    339
# dtype: int64
# 23583 Description
# LUNCH BAG PAISLEY PARK      339
# dtype: int64
# 21498 Description
# RED RETROSPOT WRAP     339
# dtype: int64
# 22784 Description
# LANTERN CREAM GAZEBO     336
# damages                    1
# dtype: int64
# 23353 Description
# 6 GIFT TAGS VINTAGE CHRISTMAS     337
# dtype: int64
# 22746 Description
# POPPY'S PLAYHOUSE LIVINGROOM     335
# dtype: int64
# 23354 Description
# 6 GIFT TAGS 50'S CHRISTMAS     335
# dtype: int64
# 22079 Description
# RIBBON REEL HEARTS DESIGN     334
# dtype: int64
# 22333 Description
# RETROSPOT PARTY BAG + STICKER SET    334
# dtype: int64
# 21240 Description
# BLUE POLKADOT CUP    334
# dtype: int64
# 22296 Description
# HEART IVORY TRELLIS LARGE    333
# dtype: int64
# 22941 Description
# CHRISTMAS LIGHTS 10 REINDEER    333
# dtype: int64
# 85049A Description
# TRADITIONAL CHRISTMAS RIBBONS    332
# dtype: int64
# 22174 Description
# PHOTO CUBE    331
# dtype: int64
# 21385 Description
# IVORY HANGING DECORATION  HEART    331
# dtype: int64
# 20679 Description
# EDWARDIAN PARASOL RED    330
# dtype: int64
# 84949 Description
# SILVER HANGING T-LIGHT HOLDER    329
# dtype: int64
# 22970 Description
# LONDON BUS COFFEE MUG    328
# dtype: int64
# 21506 Description
# FANCY FONT BIRTHDAY CARD,     327
# dtype: int64
# 22845 Description
# VINTAGE CREAM CAT FOOD CONTAINER    327
# dtype: int64
# 22418 Description
# 10 COLOUR SPACEBOY PEN    327
# dtype: int64
# 20675 Description
# BLUE POLKADOT BOWL    327
# dtype: int64
# 22739 Description
# RIBBON REEL CHRISTMAS SOCK BAUBLE    327
# dtype: int64
# 15056BL Description
# EDWARDIAN PARASOL BLACK    326
# dtype: int64
# 22158 Description
# 3 HEARTS HANGING DECORATION RUSTIC    323
# dtype: int64
# 21868 Description
# POTTING SHED TEA MUG    316
# Amazon                    1
# check                     1
# dtype: int64
# 21494 Description
# ROTATING LEAVES T-LIGHT HOLDER    322
# dtype: int64
# 22505 Description
# MEMO BOARD COTTAGE DESIGN    322
# dtype: int64
# 22963 Description
# JAM JAR WITH GREEN LID    321
# JAM JAR WITH BLUE LID       1
# dtype: int64
# 22712 Description
# CARD DOLLY GIRL     319
# dtype: int64
# 21901 Description
# KEY FOB , BACK DOOR     320
# dtype: int64
# 22899 Description
# CHILDREN'S APRON DOLLY GIRL     320
# dtype: int64
# 23247 Description
# BISCUIT TIN 50'S CHRISTMAS    320
# dtype: int64
# 21078 Description
# SET/20 STRAWBERRY PAPER NAPKINS     318
# dtype: int64
# 23265 Description
# SET OF 3 WOODEN TREE DECORATIONS    319
# dtype: int64
# 23264 Description
# SET OF 3 WOODEN SLEIGH DECORATIONS    318
# dtype: int64
# 84032A Description
# CHARLIE+LOLA PINK HOT WATER BOTTLE    318
# dtype: int64
# 22294 Description
# HEART FILIGREE DOVE  SMALL    317
# dtype: int64
# 23350 Description
# ROLL WRAP VINTAGE SPOT     316
# dtype: int64
# 23254 Description
# CHILDRENS CUTLERY DOLLY GIRL     307
# KIDS CUTLERY DOLLY GIRL            8
# dtype: int64
# 23172 Description
# REGENCY TEA PLATE PINK    315
# dtype: int64
# 21239 Description
# PINK  POLKADOT CUP    313
# dtype: int64
# 23082 Description
# SET 6 PAPER TABLE LANTERN HEARTS     313
# dtype: int64
# 23196 Description
# VINTAGE LEAF MAGNETIC NOTEPAD         285
# RETRO LEAVES MAGNETIC NOTEPAD          22
# RETO LEAVES MAGNETIC SHOPPING LIST      3
# LEAVES MAGNETIC  SHOPPING LIST          2
# dtype: int64
# 22271 Description
# FELTCRAFT DOLL ROSIE    310
# check                     1
# dtype: int64
# 20969 Description
# RED FLORAL FELTCRAFT SHOULDER BAG    311
# dtype: int64
# 21242 Description
# RED RETROSPOT PLATE     311
# dtype: int64
# 20754 Description
# RETROSPOT RED WASHING UP GLOVES    309
# Found                                1
# dtype: int64
# 82578 Description
# KITCHEN METAL SIGN    310
# dtype: int64
# 23323 Description
# WHITE WICKER STAR     309
# dtype: int64
# 21033 Description
# JUMBO BAG CHARLIE AND LOLA TOYS    302
# taig adjust no stock                 1
# dtype: int64
# 22693 Description
# GROW A FLYTRAP OR SUNFLOWER IN TIN    307
# dtype: int64
# 22109 Description
# FULL ENGLISH BREAKFAST PLATE    307
# dtype: int64
# 22605 Description
# WOODEN CROQUET GARDEN SET    307
# dtype: int64
# 22327 Description
# ROUND SNACK BOXES SET OF 4 SKULLS    306
# dtype: int64
# 22670 Description
# FRENCH WC SIGN BLUE METAL    306
# dtype: int64
# 21429 Description
# RED GINGHAM ROSE JEWELLERY BOX    302
# dtype: int64
# 22723 Description
# SET OF 6 HERB TINS SKETCHBOOK    305
# dtype: int64
# 21703 Description
# BAG 125g SWIRLY MARBLES    304
# dtype: int64
# 23126 Description
# FELTCRAFT GIRL AMELIE KIT    288
# DOLLCRAFT GIRL AMELIE          8
# DOLLCRAFT GIRL AMELIE KIT      8
# dtype: int64
# 21874 Description
# GIN AND TONIC MUG    304
# dtype: int64
# 23165 Description
# LARGE CERAMIC TOP STORAGE JAR    304
# dtype: int64
# 22508 Description
# DOORSTOP RETROSPOT HEART    304
# dtype: int64
# 72741 Description
# GRAND CHOCOLATECANDLE    303
# dtype: int64
# 22227 Description
# HANGING HEART MIRROR DECORATION     303
# dtype: int64
# 21980 Description
# PACK OF 12 RED RETROSPOT TISSUES     303
# dtype: int64
# 22131 Description
# FOOD CONTAINER SET 3 LOVE HEART     303
# dtype: int64
# 22980 Description
# PANTRY SCRUBBING BRUSH    303
# dtype: int64
# 23332 Description
# IVORY WICKER HEART LARGE    302
# dtype: int64
# 21340 Description
# CLASSIC METAL BIRDCAGE PLANT HOLDER    301
# dtype: int64
# 22721 Description
# SET OF 3 CAKE TINS SKETCHBOOK    300
# dtype: int64
# 22179 Description
# SET 10 NIGHT OWL LIGHTS    174
# SET 10 LIGHTS NIGHT OWL    125
# dtype: int64
# 16237 Description
# SLEEPING CAT ERASERS    298
# dtype: int64
# 22380 Description
# TOY TIDY SPACEBOY      297
# dtype: int64
# 22846 Description
# BREAD BIN DINER STYLE RED     296
# dtype: int64
# 22378 Description
# WALL TIDY RETROSPOT     296
# dtype: int64
# 21259 Description
# VICTORIAN SEWING BOX SMALL     295
# dtype: int64
# 84406B Description
# CREAM CUPID HEARTS COAT HANGER    293
# ?                                   1
# incorrectly made-thrown away.       1
# dtype: int64
# 22896 Description
# PEG BAG APPLES DESIGN    294
# PEG BAG APPLE DESIGN       1
# dtype: int64
# 22751 Description
# FELTCRAFT PRINCESS OLIVIA DOLL    295
# dtype: int64
# 23191 Description
# BUNDLE OF 3 RETRO NOTE BOOKS        290
# BUNDLE OF 3 RETRO EXERCISE BOOKS      5
# dtype: int64
# 47559B Description
# TEA TIME OVEN GLOVE    294
# dtype: int64
# 20992 Description
# JAZZ HEARTS PURSE NOTEBOOK    294
# dtype: int64
# 82567 Description
# AIRLINE LOUNGE,METAL SIGN    293
# dtype: int64
# 21380 Description
# WOODEN HAPPY BIRTHDAY GARLAND    294
# dtype: int64
# 22690 Description
# DOORMAT HOME SWEET HOME BLUE     293
# dtype: int64
# 23570 Description
# TRADITIONAL PICK UP STICKS GAME     293
# dtype: int64
# 22208 Description
# WOOD STAMP SET THANK YOU    293
# dtype: int64
# 23238 Description
# SET OF 4 KNICK KNACK TINS LONDON     293
# dtype: int64
# 22895 Description
# SET OF 2 TEA TOWELS APPLE AND PEARS    292
# dtype: int64
# 22563 Description
# HAPPY STENCIL CRAFT    292
# dtype: int64
# 48188 Description
# DOORMAT WELCOME PUPPIES    291
# dtype: int64
# 21329 Description
# DINOSAURS  WRITING SET     291
# dtype: int64
# 22110 Description
# BIRD HOUSE HOT WATER BOTTLE    290
# dtype: int64
# 23367 Description
# SET 12 COLOUR PENCILS SPACEBOY     290
# dtype: int64
# 22817 Description
# CARD SUKI BIRTHDAY    290
# dtype: int64
# 21899 Description
# GARAGE KEY FOB             151
# KEY FOB , GARAGE DESIGN    139
# dtype: int64
# 22840 Description
# ROUND CAKE TIN VINTAGE RED    289
# dtype: int64
# 22716 Description
# CARD CIRCUS PARADE    289
# dtype: int64
# 21164 Description
# HOME SWEET HOME METAL SIGN     287
# dtype: int64
# 22768 Description
# FAMILY PHOTO FRAME CORNICE    287
# dtype: int64
# 22432 Description
# WATERING CAN PINK BUNNY    287
# dtype: int64
# 20983 Description
# 12 PENCILS TALL TUBE RED RETROSPOT    287
# dtype: int64
# 22991 Description
# GIRAFFE WOODEN RULER    287
# dtype: int64
# 23234 Description
# BISCUIT TIN VINTAGE CHRISTMAS    286
# dtype: int64
# 22798 Description
# ANTIQUE GLASS DRESSING TABLE POT    285
# dtype: int64
# 85048 Description
# 15CM CHRISTMAS GLASS BALL 20 LIGHTS    285
# dtype: int64
# 23110 Description
# PARISIENNE KEY CABINET     285
# dtype: int64
# 23000 Description
# TRAVEL CARD WALLET TRANSPORT    285
# dtype: int64
# 21756 Description
# BATH BUILDING BLOCK WORD    285
# dtype: int64
# 23306 Description
# SET OF 36 DOILIES PANTRY DESIGN    247
# SET OF 36 PANTRY PAPER DOILIES      34
# dtype: int64
# 22644 Description
# CERAMIC CHERRY CAKE MONEY BANK    283
# dtype: int64
# 22738 Description
# RIBBON REEL SNOWY VILLAGE    283
# dtype: int64
# 22602 Description
# RETROSPOT WOODEN HEART DECORATION    255
# CHRISTMAS RETROSPOT HEART WOOD        28
# dtype: int64
# 22419 Description
# LIPSTICK PEN RED    282
# dtype: int64
# 23076 Description
# ICE CREAM SUNDAE LIP GLOSS    280
# dtype: int64
# 85014A Description
# BLACK/BLUE POLKADOT UMBRELLA    280
# dtype: int64
# 22361 Description
# GLASS JAR DAISY FRESH COTTON WOOL    279
# dtype: int64
# 22904 Description
# CALENDAR PAPER CUT DESIGN    279
# dtype: int64
# 23052 Description
# RECYCLED ACAPULCO MAT TURQUOISE    279
# dtype: int64
# 22971 Description
# QUEENS GUARD COFFEE MUG    279
# dtype: int64
# 23109 Description
# PACK OF SIX LED TEA LIGHTS    211
# LED TEA LIGHTS                 67
# dtype: int64
# 22030 Description
# SWALLOWS GREETING CARD    277
# ??                          1
# dtype: int64
# 23144 Description
# ZINC T-LIGHT HOLDER STARS SMALL    278
# dtype: int64
# 23177 Description
# TREASURE ISLAND BOOK BOX    278
# dtype: int64
# 23118 Description
# PARISIENNE JEWELLERY DRAWER     275
# Breakages                         1
# check                             1
# dotcom adjust                     1
# dtype: int64
# 21179 Description
# NO JUNK MAIL METAL SIGN    275
# damaged                      1
# dtype: int64
# 85049G Description
# CHOCOLATE BOX RIBBONS     277
# dtype: int64
# 21981 Description
# PACK OF 12 WOODLAND TISSUES     277
# dtype: int64
# 22435 Description
# SET OF 9 HEART SHAPED BALLOONS    275
# ?missing                            1
# dtype: int64
# 22274 Description
# FELTCRAFT DOLL EMILY    276
# dtype: int64
# 22089 Description
# PAPER BUNTING VINTAGE PAISLEY    276
# dtype: int64
# 22156 Description
# HEART DECORATION WITH PEARLS     276
# dtype: int64
# 85199S Description
# SMALL HANGING IVORY/RED WOOD BIRD    275
# dtype: int64
# 21098 Description
# CHRISTMAS TOILET ROLL    271
# damages?                   1
# had been put aside         1
# dtype: int64
# 21509 Description
# COWBOYS AND INDIANS BIRTHDAY CARD     274
# dtype: int64
# 22596 Description
# CHRISTMAS STAR WISH LIST CHALKBOARD    274
# dtype: int64
# 84832 Description
# ZINC WILLIE WINKIE  CANDLE STICK    274
# dtype: int64
# 22995 Description
# TRAVEL CARD WALLET SUKI    273
# dtype: int64
# 22303 Description
# COFFEE MUG APPLES DESIGN    273
# dtype: int64
# 22622 Description
# BOX OF VINTAGE ALPHABET BLOCKS    272
# dtype: int64
# 23147 Description
# SINGLE ANTIQUE ROSE HOOK IVORY    272
# dtype: int64
# 21810 Description
# CHRISTMAS HANGING STAR WITH BELL    270
# check                                 1
# dtype: int64
# 23080 Description
# RED METAL BOX TOP SECRET    271
# dtype: int64
# 22816 Description
# CARD MOTORBIKE SANTA    271
# dtype: int64
# 22754 Description
# SMALL RED BABUSHKA NOTEBOOK     270
# dtype: int64
# 21257 Description
# VICTORIAN SEWING BOX MEDIUM    268
# ?                                1
# dtype: int64
# 22170 Description
# PICTURE FRAME WOOD TRIPLE PORTRAIT    270
# dtype: int64
# 22301 Description
# COFFEE MUG CAT + BIRD DESIGN    270
# dtype: int64
# 22819 Description
# BIRTHDAY CARD, RETRO SPOT    270
# dtype: int64
# 23184 Description
# BULL DOG BOTTLE OPENER    270
# dtype: int64
# 21108 Description
# FAIRY CAKE FLANNEL ASSORTED COLOUR    270
# dtype: int64
# 20978 Description
# 36 PENCILS TUBE SKULLS    270
# dtype: int64
# 22815 Description
# CARD PSYCHEDELIC APPLES    269
# dtype: int64
# 21428 Description
# SET3 BOOK BOX GREEN GINGHAM FLOWER     269
# dtype: int64
# 23582 Description
# VINTAGE DOILY JUMBO BAG RED     269
# dtype: int64
# 22737 Description
# RIBBON REEL CHRISTMAS PRESENT     269
# dtype: int64
# 23571 Description
# TRADITIONAL NAUGHTS & CROSSES    268
# dtype: int64
# 22028 Description
# PENNY FARTHING BIRTHDAY CARD    265
# dtype: int64
# 84050 Description
# PINK HEART SHAPE EGG FRYING PAN    265
# check                                1
# counted                              1
# dtype: int64
# 22534 Description
# MAGIC DRAWING SLATE SPACEBOY     267
# dtype: int64
# 23100 Description
# SILVER BELLS TABLE DECORATION    267
# dtype: int64
# 22064 Description
# PINK DOUGHNUT TRINKET POT     266
# dtype: int64
# 20970 Description
# PINK FLORAL FELTCRAFT SHOULDER BAG    266
# dtype: int64
# 21041 Description
# RED RETROSPOT OVEN GLOVE DOUBLE    266
# dtype: int64
# 20982 Description
# 12 PENCILS TALL TUBE SKULLS    266
# dtype: int64
# 22571 Description
# ROCKING HORSE RED CHRISTMAS     266
# dtype: int64
# 22065 Description
# CHRISTMAS PUDDING TRINKET POT     265
# dtype: int64
# 22906 Description
# 12 MESSAGE CARDS WITH ENVELOPES    265
# dtype: int64
# 21507 Description
# ELEPHANT, BIRTHDAY CARD,     168
# ELEPHANT BIRTHDAY CARD        97
# dtype: int64
# 21531 Description
# RED RETROSPOT SUGAR JAM BOWL    264
# dtype: int64
# 22772 Description
# PINK DRAWER KNOB ACRYLIC EDWARDIAN    264
# dtype: int64
# 23148 Description
# MINIATURE ANTIQUE ROSE HOOK IVORY    260
# MINITURE ANTIQUE ROSE HOOK IVORY       4
# dtype: int64
# 23534 Description
# WALL ART STOP FOR TEA     223
# STOP FOR TEA WALL ART      41
# dtype: int64
# 84997A Description
# CHILDRENS CUTLERY POLKADOT GREEN      189
# GREEN 3 PIECE POLKADOT CUTLERY SET     74
# dtype: int64
# 22358 Description
# KINGS CHOICE TEA CADDY     262
# dtype: int64
# 23329 Description
# DECORATIVE WICKER HEART LARGE    262
# dtype: int64
# 21937 Description
# STRAWBERRY   PICNIC BAG    259
# ?                            1
# found                        1
# dtype: int64
# 84032B Description
# CHARLIE + LOLA RED HOT WATER BOTTLE    262
# dtype: int64
# 23229 Description
# VINTAGE DONKEY TAIL GAME     257
# DONKEY TAIL GAME               4
# dtype: int64
# 23112 Description
# PARISIENNE CURIO CABINET    261
# dtype: int64
# 21811 Description
# HANGING HEART WITH BELL              229
# CHRISTMAS HANGING HEART WITH BELL     29
# check                                  2
# dtype: int64
# 21539 Description
# RED RETROSPOT BUTTER DISH    259
# check                          1
# damages?                       1
# dtype: int64
# 22295 Description
# HEART FILIGREE DOVE LARGE    261
# dtype: int64
# 23166 Description
# MEDIUM CERAMIC TOP STORAGE JAR    260
# dtype: int64
# 23231 Description
# WRAP DOILEY DESIGN       164
# WRAP  VINTAGE DOILY       94
# WRAP  VINTAGE DOILEY       2
# dtype: int64
# 21116 Description
# OWL DOORSTOP    259
# dtype: int64
# 23158 Description
# SET OF 5 LUCKY CAT MAGNETS     260
# dtype: int64
# 23078 Description
# ICE CREAM PEN LIP GLOSS     259
# dtype: int64
# 23197 Description
# SKETCHBOOK MAGNETIC SHOPPING LIST    256
# VEGETABLE MAGNETIC  SHOPPING LIST      3
# dtype: int64
# 22398 Description
# MAGNETS PACK OF 4 SWALLOWS    258
# dtype: int64
# 22796 Description
# PHOTO FRAME 3 CLASSIC HANGING      257
# Not rcvd in 10/11/2010 delivery      1
# dtype: int64
# 22775 Description
# PURPLE DRAWERKNOB ACRYLIC EDWARDIAN    256
# dtype: int64
# 20981 Description
# 12 PENCILS TALL TUBE WOODLAND    256
# dtype: int64
# 22755 Description
# SMALL PURPLE BABUSHKA NOTEBOOK     256
# dtype: int64
# 21327 Description
# SKULLS WRITING SET     256
# dtype: int64
# 23146 Description
# TRIPLE HOOK ANTIQUE IVORY ROSE    256
# dtype: int64
# 23012 Description
# GLASS APOTHECARY BOTTLE PERFUME    256
# dtype: int64
# 22653 Description
# ...
# 22885 Description
# NUMBER TILE VINTAGE FONT 6     29
# dtype: int64
# 85039a Description
# SET/4 RED MINI ROSE CANDLE IN BOWL    29
# dtype: int64
# 84974 Description
# S/2 ZINC HEART DESIGN PLANTERS    29
# dtype: int64
# 84661B Description
# BLACK SQUARE TABLE CLOCK    29
# dtype: int64
# 47021G Description
# SET/6 BEAD COASTERS GAUZE BAG GOLD    27
# dtype: int64
# 37476 Description
# CONDIMENT TRAY 4 BOWLS AND 4 SPOONS    27
# dtype: int64
# 22053 Description
# EMPIRE DESIGN ROSETTE    29
# dtype: int64
# 20781 Description
# GOLD EAR MUFF HEADPHONES    29
# dtype: int64
# 90201A Description
# PURPLE ENAMEL FLOWER RING    29
# dtype: int64
# 84926F Description
# PSYCHEDELIC TILE COASTER    29
# dtype: int64
# 84249A Description
# GREETING CARD,SQUARE, DOUGHNUTS    27
# check                               1
# damaged                             1
# dtype: int64
# 21375 Description
# LARGE CAMPHOR WOOD FIELD MUSHROOM     29
# dtype: int64
# 84228 Description
# HEN HOUSE W CHICK STANDING       25
# HEN HOUSE WITH CHICK STANDING     3
# crushed                           1
# dtype: int64
# 22391 Description
# PAPERWEIGHT HOME SWEET HOME    29
# dtype: int64
# 22825 Description
# DECORATIVE PLANT POT WITH FRIEZE    29
# dtype: int64
# 20705 Description
# MRS ROBOT SOFT TOY    29
# dtype: int64
# 23042 Description
# PAPER LANTERN 7 POINT SNOW STAR    29
# dtype: int64
# 23071 Description
# MARIE ANTOINETTE TRINKET BOX GOLD    27
# MARIE ANTOIENETT TRINKET BOX GOLD     1
# damages                               1
# dtype: int64
# 90200C Description
# BLUE SWEETHEART BRACELET    27
# dtype: int64
# 72130 Description
# COLUMBIAN CANDLE ROUND    28
# dtype: int64
# 90214M Description
# LETTER "M" BLING KEY RING    28
# dtype: int64
# 47518F Description
# ICON PLACEMAT POP ART ELVIS    28
# dtype: int64
# 47559b Description
# TEA TIME OVEN GLOVE    28
# dtype: int64
# 21100 Description
# CHARLIE AND LOLA CHARLOTTE BAG    27
# Damaged                            1
# dtype: int64
# 21898 Description
# POTTING SHED ROSE CANDLE    25
# dtype: int64
# 21129 Description
# SILVER FISHING GNOME     28
# dtype: int64
# 85200 Description
# BUNNY EGG BOX    27
# dtype: int64
# 23471 Description
# SIX DRAWER OFFICE TIDY    28
# dtype: int64
# 84457 Description
# SET/3 RABBITS FLOWER SKIPPPING ROPE    28
# dtype: int64
# 20782 Description
# CAMOUFLAGE EAR MUFF HEADPHONES    28
# dtype: int64
# 21131 Description
# GOLD STANDING GNOME    28
# dtype: int64
# 23466 Description
# TUSCAN VILLA DOVECOTE BIRD FEEDER    24
# TUSCAN VILLA DOVECOTE                 4
# dtype: int64
# 21197 Description
# MULTICOLOUR  CONFETTI IN TUBE    28
# dtype: int64
# 84192 Description
# ASSORTED COLOUR METAL CAT     28
# dtype: int64
# 23417 Description
# BATHROOM HOOK    28
# dtype: int64
# 21292 Description
# SMALL STRIPES CHOCOLATE GIFT BAG     28
# dtype: int64
# 21562 Description
# HAWAIIAN GRASS SKIRT     28
# dtype: int64
# 21662 Description
# VINTAGE GLASS COFFEE CADDY    26
# dtype: int64
# 35637A Description
# IVORY STRING CURTAIN WITH POLE     28
# dtype: int64
# 90013C Description
# GREEN VINTAGE EARRINGS     28
# dtype: int64
# 90059A Description
# DIAMANTE HAIR GRIP PACK/2 CRYSTAL    28
# dtype: int64
# 90086 Description
# CRYSTAL FROG PHONE CHARM    28
# dtype: int64
# 84870C Description
# GREEN GEISHA GIRL     28
# dtype: int64
# 23019 Description
# SMALL APOTHECARY MEASURING JAR     28
# dtype: int64
# 23021 Description
# GLASS BONNE JAM JAR    28
# dtype: int64
# 17091A Description
# LAVENDER INCENSE IN TIN    26
# found                       1
# dtype: int64
# 23023 Description
# RIDGED BONNE JAM JAR T-LIGHT HOLDER    28
# dtype: int64
# 23044 Description
# PAPER LANTERN 9 POINT HOLLY STAR S     23
# PAPER LANTERN 9 POINT HOLLY STAR 23     5
# dtype: int64
# 22486 Description
# PLASMATRONIC LAMP    28
# dtype: int64
# 22459 Description
# CAST IRON HOOK GARDEN TROWEL    25
# ?lost                            1
# dtype: int64
# 22353 Description
# LUNCH BOX WITH CUTLERY FAIRY CAKES     26
# dtype: int64
# 22040 Description
# BOTANICAL ROSE GIFT WRAP    28
# dtype: int64
# 23492 Description
# VINTAGE JINGLE BELLS WREATH    28
# dtype: int64
# 21738 Description
# COSY SLIPPER SHOES SMALL  RED     25
# dtype: int64
# 22656 Description
# VINTAGE BLUE KITCHEN CABINET    26
# dtype: int64
# 22761 Description
# CHEST 7 DRAWER MA CAMPAGNE    27
# dtype: int64
# 21631 Description
# HIPPY CHIC DECORATIVE PARASOL    27
# dtype: int64
# 16015 Description
# MEDIUM CHINESE STYLE SCISSOR    24
# dtype: int64
# 21689 Description
# SILVER VANILLA  FLOWER CANDLE POT    26
# wrong barcode                         1
# dtype: int64
# 23560 Description
# SET OF 6 RIBBONS COUNTRY STYLE    27
# dtype: int64
# 46000U Description
# POLYESTER FILLER PAD 30CMx30CM    26
# check                              1
# dtype: int64
# 84823 Description
# DANISH ROSE FOLDING CHAIR    25
# dtype: int64
# 79164 Description
# BLACK WINE GLASS              22
# damages/credits from ASOS.     1
# dtype: int64
# 84352 Description
# SILVER CHRISTMAS TREE BAUBLE STAND     26
# Damages/samples                         1
# dtype: int64
# 81952V Description
# ROUND PURPLE CLOCK WITH SUCKER    27
# dtype: int64
# 20763 Description
# DAISY SKETCHBOOK     27
# dtype: int64
# 84051 Description
# ASS COLOUR GLOWING TIARAS    27
# dtype: int64
# 35599B Description
# BLACK CHRISTMAS TREE 120CM    27
# dtype: int64
# 17084R Description
# ASSORTED INCENSE PACK    27
# dtype: int64
# 90062 Description
# CARNIVAL BRACELET    27
# dtype: int64
# 90096 Description
# NECKLACE+BRACELET SET BLUE BLOSSOM    26
# dtype: int64
# 84508C Description
# BLUE CIRCLES DESIGN TEDDY    26
# check                         1
# dtype: int64
# 20819 Description
# SILVER TEDDY BEAR    27
# dtype: int64
# 90197B Description
# BLACK GLASS BRACELET W HEART CHARMS    27
# dtype: int64
# 90019A Description
# SILVER M.O.P ORBIT BRACELET    27
# dtype: int64
# 84509c Description
# SET OF 4 POLKADOT PLACEMATS     27
# dtype: int64
# 82001s Description
# SILVER RECORD COVER FRAME    15
# VINYL RECORD FRAME SILVER    12
# dtype: int64
# 84952A Description
# CLEAR LOVE BIRD T-LIGHT HOLDER    26
# dtype: int64
# 21904 Description
# HOUSE WRECKING METAL SIGN     25
# dtype: int64
# 90192 Description
# JADE DROP EARRINGS W FILIGREE    26
# dtype: int64
# 20897 Description
# VINTAGE NOTEBOOK PARIS DAYS    26
# dtype: int64
# 23580 Description
# SNACK TRAY HAPPY FOREST      26
# dtype: int64
# 23022 Description
# SMALL BONNE JAM JAR  T-LIGHT HOLDER    26
# dtype: int64
# 84884a Description
# ANT WHITE WIRE HEART SPIRAL    26
# dtype: int64
# 23047 Description
# PAPER LANTERN 5 POINT SEQUIN STAR     22
# PAPER LANTERN 5 POINT STUDDED STAR     4
# dtype: int64
# 23045 Description
# PAPER LANTERN 5 POINT STAR MOON       21
# PAPER LANTERN 5 POINT STAR MOON 30     5
# dtype: int64
# 17096 Description
# ASSORTED LAQUERED INCENSE HOLDERS    24
# dtype: int64
# 21841 Description
# BABY MOUSE RED GINGHAM DRESS    23
# dtype: int64
# 21632 Description
# VINTAGE PINK DECORATIVE PARASOL    24
# dtype: int64
# 84870B Description
# BLUE GEISHA GIRL     26
# dtype: int64
# 85230G Description
# ORANGE VOTIVE CANDLE    26
# dtype: int64
# 85230E Description
# STRAWBRY SCENTED VOTIVE CANDLE    24
# Damaged                            1
# dtype: int64
# 21503 Description
# TOYBOX  WRAP     24
# dtype: int64
# 21456 Description
# 2 PICTURE BOOK EGGS EASTER CHICKS    26
# dtype: int64
# 21418 Description
# STARFISH SOAP DISH    26
# dtype: int64
# 21202 Description
# DOLLY HONEYCOMB GARLAND    26
# dtype: int64
# 20773 Description
# BLUE PAISLEY NOTEBOOK    24
# dtype: int64
# 84600 Description
# NEW BAROQUE JEWELLERY BOX     26
# dtype: int64
# 22873 Description
# NUMBER TILE COTTAGE GARDEN 5    26
# dtype: int64
# 90160C Description
# TURQ+RED BOUDICCA LARGE BRACELET    26
# dtype: int64
# 16169M Description
# WRAP DAISY CARPET     26
# dtype: int64
# 21089 Description
# SET/6 GREEN SPRING PAPER CUPS    25
# damaged                           1
# dtype: int64
# 21082 Description
# SET/20 FRUIT SALAD PAPER NAPKINS     25
# found                                 1
# dtype: int64
# 15056p Description
# EDWARDIAN PARASOL PINK    26
# dtype: int64
# 90175A Description
# WHITE GLASS CHUNKY CHARM BRACELET    25
# dtype: int64
# 90214R Description
# LETTER "R" BLING KEY RING    25
# dtype: int64
# 84800L Description
# LARGE WHITE/PINK ROSE ART FLOWER    23
# wet damaged                          1
# dtype: int64
# 90087 Description
# CRYSTAL SEA HORSE PHONE CHARM    25
# dtype: int64
# 77101A Description
# UNION FLAG WINDSOCK    23
# dtype: int64
# 90030B Description
# RED KUKUI COCONUT SEED NECKLACE    25
# dtype: int64
# 84989a Description
# 75 GREEN FAIRY CAKE CASES    25
# dtype: int64
# 90003C Description
# MIDNIGHT BLUE PAIR HEART HAIR SLIDE    25
# dtype: int64
# 90201B Description
# BLACK ENAMEL FLOWER RING    25
# dtype: int64
# 72801c Description
# 4 ROSE PINK DINNER CANDLES    25
# dtype: int64
# 23141 Description
# TRIPLE WIRE HOOK PINK HEART    25
# dtype: int64
# 21946 Description
# PARTY TIME DESIGN FLANNEL    25
# dtype: int64
# 21038 Description
# SET/4 MODERN VINTAGE COTTON NAPKINS    24
# dtype: int64
# 22127 Description
# PARTY CONES CARNIVAL ASSORTED    23
# Dotcom sold in 6's                1
# sold in set?                      1
# dtype: int64
# 22871 Description
# NUMBER TILE COTTAGE GARDEN 3     25
# dtype: int64
# 21445 Description
# 12 PINK ROSE PEG PLACE SETTINGS    22
# dtype: int64
# 22875 Description
# NUMBER TILE COTTAGE GARDEN 7    25
# dtype: int64
# 21364 Description
# PEACE SMALL WOOD LETTERS    25
# dtype: int64
# 21750 Description
# LARGE SKULL WINDMILL    25
# dtype: int64
# 22886 Description
# NUMBER TILE VINTAGE FONT 7    25
# dtype: int64
# 35598B Description
# BLACK CHRISTMAS TREE 60CM    25
# dtype: int64
# 22407 Description
# MONEY BOX FIRST ADE DESIGN    14
# MONEY BOX FIRST AID DESIGN    11
# dtype: int64
# 21293 Description
# MIRRORED DOVE WALL DECORATION    25
# dtype: int64
# 23416 Description
# CHAMBRE HOOK    25
# dtype: int64
# 21457 Description
# 2 PICTURE BOOK EGGS EASTER DUCKS    25
# dtype: int64
# 23016 Description
# GLASS TWIST BON BON JAR    25
# dtype: int64
# 22458 Description
# CAST IRON HOOK GARDEN FORK    23
# Missing                        1
# dtype: int64
# 10080 Description
# GROOVY CACTUS INFLATABLE    22
# check                        1
# dtype: int64
# 84907 Description
# PINK YELLOW PATCH CUSHION COVER    23
# dtype: int64
# 22394 Description
# PAPERWEIGHT KINGS CHOICE     24
# dtype: int64
# 23519 Description
# EMBROIDERED RIBBON REEL CLAIRE    24
# dtype: int64
# 51008 Description
# AFGHAN SLIPPER SOCK PAIR    23
# dtype: int64
# 84595E Description
# LARGE TORTILLA DESIGN RED BOWL    23
# dtype: int64
# 84658 Description
# WHITE STITCHED CUSHION COVER    24
# dtype: int64
# 85106 Description
# CUT GLASS HEXAGON T-LIGHT HOLDER    21
# dtype: int64
# 21277 Description
# FRENCH STYLE EMBOSSED HEART CABINET    24
# dtype: int64
# 37479B Description
# CUBIC MUG FLOCK BLUE ON BROWN    21
# sold as set by dotcom             1
# dtype: int64
# 84535A Description
# ENGLISH ROSE NOTEBOOK A6 SIZE    21
# dtype: int64
# 90214N Description
# LETTER "N" BLING KEY RING    24
# dtype: int64
# 21547 Description
# CERAMIC BIRDHOUSE CRESTED TIT SMALL    23
# dtype: int64
# 23116 Description
# VEGETABLE GARDEN CHOPPING BOARD    23
# Damaged                             1
# dtype: int64
# 35833P Description
# 4 PINK FLOCK CHRISTMAS BALLS    23
# check                            1
# dtype: int64
# 47481 Description
# 50CM METAL STRING WITH  7 CLIPS    24
# dtype: int64
# 21694 Description
# SMALL REGAL  SILVER CANDLEPOT     24
# dtype: int64
# 90147 Description
# CHUNKY SILVER NECKLACE PASTEL FLOWE    24
# dtype: int64
# 90183A Description
# AMBER DROP EARRINGS W LONG BEADS    24
# dtype: int64
# 35921 Description
# EASTER BUNNY HANGING GARLAND    24
# dtype: int64
# 21476 Description
# STEEL SWEETHEART ROUND TABLE CREAM    24
# dtype: int64
# 84510c Description
# SET OF 4 POLKADOT COASTERS    23
# dtype: int64
# 84685 Description
# BEACH HUT KEY CABINET    22
# dtype: int64
# 71101E Description
# STANDING FAIRY POLE SUPPORT     23
# dtype: int64
# 23429 Description
# RED RETRO KITCHEN WALL CLOCK    23
# dtype: int64
# 20760 Description
# GARDEN PATH POCKET BOOK    22
# dtype: int64
# 84915 Description
# HAND TOWEL PINK FLOWER AND DAISY    23
# dtype: int64
# 20756 Description
# GREEN FERN POCKET BOOK    22
# dtype: int64
# 90174 Description
# BUTTERFLY HAIR BAND    23
# dtype: int64
# 22033 Description
# BOTANICAL ROSE GREETING CARD    22
# dtype: int64
# 85014b Description
# RED RETROSPOT UMBRELLA    23
# dtype: int64
# 84507B Description
# STRIPES DESIGN MONKEY DOLL    22
# dtype: int64
# 37444A Description
# YELLOW BREAKFAST CUP AND SAUCER    20
# dtype: int64
# 84509E Description
# SET OF 4 CAROUSEL PLACEMATS     23
# dtype: int64
# 21320 Description
# GLASS CHALICE GREEN  LARGE     21
# broken                          1
# dtype: int64
# 90057 Description
# DIAMANTE RING ASSORTED IN BOX.    22
# crushed boxes                      1
# dtype: int64
# 23015 Description
# CORDIAL GLASS JUG    21
# CORDIAL JUG           2
# dtype: int64
# 85197 Description
# SET OF 12 MINI BUNNIES IN A BUCKET    20
# dtype: int64
# 23043 Description
# PAPER LANTERN 9 POINT HOLLY STAR L     20
# PAPER LANTERN 9 POINT HOLLY STAR 40     3
# dtype: int64
# 23017 Description
# APOTHECARY MEASURING JAR    23
# dtype: int64
# 22887 Description
# NUMBER TILE VINTAGE FONT 8    23
# dtype: int64
# 84859C Description
# PINK DISCO HANDBAG    22
# wet?                   1
# dtype: int64
# 23149 Description
# ANTIQUE IVORY WIRE BOWL SMALL    23
# dtype: int64
# 23137 Description
# ZINC WIRE SWEETHEART LETTER TRAY    23
# dtype: int64
# 20941 Description
# FROG CANDLE    21
# dtype: int64
# 84877D Description
# BLUE ROUND COMPACT MIRROR    19
# ?                             1
# found                         1
# dtype: int64
# 84592 Description
# CROCHET ROSE PURSE WITH SUEDE BACK    22
# dtype: int64
# 84569B Description
# PACK 3 FIRE ENGINE/CAR PATCHES    20
# dtype: int64
# 84559a Description
# 3D SHEET OF DOG STICKERS    22
# dtype: int64
# 90201C Description
# RED ENAMEL FLOWER RING    22
# dtype: int64
# 90120C Description
# GREEN MURANO TWIST BRACELET    22
# dtype: int64
# 90014A Description
# SILVER/MOP ORBIT NECKLACE       15
# SILVER M.O.P. ORBIT NECKLACE     6
# check                            1
# dtype: int64
# 84429A Description
# MEDIUM PINK BUDDHA HEAD     22
# dtype: int64
# 84609 Description
# TALL ROCOCO CANDLE HOLDER    21
# damages                       1
# dtype: int64
# 20980 Description
# 36 PENCILS TUBE POSY    21
# dtype: int64
# 85232B Description
# SET OF 3 BABUSHKA STACKING TINS    20
# dtype: int64
# 90143 Description
# SILVER BRACELET W PASTEL FLOWER    22
# dtype: int64
# 21686 Description
# MEDINA STAMPED METAL STOOL    21
# dtype: int64
# 35004G Description
# SET OF 3 GOLD FLYING DUCKS    22
# dtype: int64
# 21132 Description
# SILVER STANDING GNOME       22
# dtype: int64
# 85020 Description
# ROUND PINK HEART MIRROR    22
# dtype: int64
# 35933 Description
# PINK STOCKING CHRISTMAS DECORATION    19
# dtype: int64
# 47369B Description
# BLUE GREEN EMBROIDERY COSMETIC BAG    22
# dtype: int64
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [68], in <cell line: 1>()
#       1 for index in multistockcodes:
# ----> 2     print(index,df[df["StockCode"]==index].value_counts("Description"))
#
# File ~\anaconda3\envs\programming\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~\anaconda3\envs\programming\lib\site-packages\pandas\core\arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File ~\anaconda3\envs\programming\lib\site-packages\pandas\core\series.py:5623, in Series._cmp_method(self, other, op)
#    5620 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    5622 with np.errstate(all="ignore"):
# -> 5623     res_values = ops.comparison_op(lvalues, rvalues, op)
#    5625 return self._construct_result(res_values, name=res_name)
#
# File ~\anaconda3\envs\programming\lib\site-packages\pandas\core\ops\array_ops.py:283, in comparison_op(left, right, op)
#     280     return invalid_comparison(lvalues, rvalues, op)
#     282 elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 283     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     285 else:
#     286     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File ~\anaconda3\envs\programming\lib\site-packages\pandas\core\ops\array_ops.py:74, in comp_method_OBJECT_ARRAY(op, x, y)
#      72 else:
#      73     result = libops.scalar_compare(x.ravel(), y, op)
# ---> 74 return result.reshape(x.shape)
#
# KeyboardInterrupt:

# %%
print(multistockcodes[1],df[df["StockCode"]==multistockcodes[1]].value_counts("Description"))
# Out:
# 22423 Description
# REGENCY CAKESTAND 3 TIER    2200
# damages                        2
# faulty                         1
# dtype: int64

# %%
df_stockcodes = df.value_counts("StockCode")

# %%
df[df["StockCode"]=="85123A"]
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 0         536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 49        536373    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 66        536375    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 220       536390    85123A  WHITE HANGING HEART T-LIGHT HOLDER        64
# 262       536394    85123A  WHITE HANGING HEART T-LIGHT HOLDER        32
# ...          ...       ...                                 ...       ...
# 539342    581439    85123A  CREAM HANGING HEART T-LIGHT HOLDER         1
# 539979    581452    85123A  WHITE HANGING HEART T-LIGHT HOLDER        32
# 540217    581472    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 540837    581492    85123A  CREAM HANGING HEART T-LIGHT HOLDER         3
# 541639    581538    85123A  CREAM HANGING HEART T-LIGHT HOLDER         1
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# 49       12/1/2010 9:02       2.55     17850.0  United Kingdom
# 66       12/1/2010 9:32       2.55     17850.0  United Kingdom
# 220     12/1/2010 10:19       2.55     17511.0  United Kingdom
# 262     12/1/2010 10:39       2.55     13408.0  United Kingdom
# ...                 ...        ...         ...             ...
# 539342  12/8/2011 16:30       5.79         NaN  United Kingdom
# 539979  12/8/2011 18:03       2.55     17675.0  United Kingdom
# 540217  12/8/2011 19:55       2.95     15796.0  United Kingdom
# 540837  12/9/2011 10:03       5.79         NaN  United Kingdom
# 541639  12/9/2011 11:34       2.95     14446.0  United Kingdom
#
# [2313 rows x 8 columns]

# %%
df.groupby("StockCode").sum()
# Out:
#               Quantity  UnitPrice  CustomerID
# StockCode
# 10002             1037      77.15    723842.0
# 10080              495       9.04    333014.0
# 10120              193       6.30    484879.0
# 10123C             -13       1.95     46701.0
# 10123G             -38       0.00         0.0
# ...                ...        ...         ...
# gift_0001_20        20     150.38         0.0
# gift_0001_30        37     175.53         0.0
# gift_0001_40         3     100.70         0.0
# gift_0001_50         4     167.56         0.0
# m                    1       2.55         0.0
#
# [4070 rows x 3 columns]

# %%
df_price = df[df["StockCode"]=="85123A"].groupby("MonthYear").mean()
df_price.reset_index(inplace=True)
df_price
# Out:
#    MonthYear   Quantity  UnitPrice    CustomerID
# 0    2010-12  13.665254   3.111737  15991.014085
# 1    2011-01  30.677778   3.031389  15494.233533
# 2    2011-02  12.577181   3.122617  15450.230769
# 3    2011-03  10.060914   3.102538  15418.241379
# 4    2011-04  10.364130   3.115272  15585.143750
# 5    2011-05  18.058824   2.978100  15399.651741
# 6    2011-06  38.222973   3.094459  15766.761538
# 7    2011-07  17.976048   3.168084  15478.120805
# 8    2011-08  13.585526   2.987697  15577.379562
# 9    2011-09  13.720670   3.128212  15557.950617
# 10   2011-10  10.041667   3.201667  15574.907895
# 11   2011-11  17.606061   3.139242  15456.264463
# 12   2011-12  11.970588   3.267059  15444.200000

# %%
plt.figure(figsize = (15,8))
sns.lineplot(x = "Quantity", y = 'UnitPrice',data = df)
# Out:
# <AxesSubplot:xlabel='Quantity', ylabel='UnitPrice'>

# %%
df[df["StockCode"]=="22423"].value_counts("Description")
# Out:
# Description
# REGENCY CAKESTAND 3 TIER    2200
# damages                        2
# faulty                         1
# dtype: int64

# %%
df[df["StockCode"]=="85099B"].value_counts("Description")
# Out:
# Description
# JUMBO BAG RED RETROSPOT    2159
# dtype: int64

# %%
df[df["StockCode"]=="47566"].value_counts("Description")
# Out:
# Description
# PARTY BUNTING    1727
# dtype: int64

# %%
df[df["StockCode"]=="20725"].value_counts("Description")
# Out:
# Description
# LUNCH BAG RED RETROSPOT    1638
# LUNCH BAG RED SPOTTY          1
# dtype: int64

# %%
df[df["Quantity"]<1]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice  CustomerID         Country        Date  \
# 141    2010-12-01 09:41:00      27.50     14527.0  United Kingdom  2010-12-01
# 154    2010-12-01 09:49:00       4.65     15311.0  United Kingdom  2010-12-01
# 235    2010-12-01 10:24:00       1.65     17548.0  United Kingdom  2010-12-01
# 236    2010-12-01 10:24:00       0.29     17548.0  United Kingdom  2010-12-01
# 237    2010-12-01 10:24:00       0.29     17548.0  United Kingdom  2010-12-01
# ...                    ...        ...         ...             ...         ...
# 540449 2011-12-09 09:57:00       0.83     14397.0  United Kingdom  2011-12-09
# 541541 2011-12-09 10:28:00     224.69     15498.0  United Kingdom  2011-12-09
# 541715 2011-12-09 11:57:00      10.95     15311.0  United Kingdom  2011-12-09
# 541716 2011-12-09 11:58:00       1.25     17315.0  United Kingdom  2011-12-09
# 541717 2011-12-09 11:58:00       1.25     17315.0  United Kingdom  2011-12-09
#
#        MonthYear
# 141      2010-12
# 154      2010-12
# 235      2010-12
# 236      2010-12
# 237      2010-12
# ...          ...
# 540449   2011-12
# 541541   2011-12
# 541715   2011-12
# 541716   2011-12
# 541717   2011-12
#
# [10624 rows x 10 columns]

# %%
df[df["Quantity"]<-10000]
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 61624    C541433     23166  MEDIUM CERAMIC TOP STORAGE JAR    -74215
# 540422   C581484     23843     PAPER CRAFT , LITTLE BIRDIE    -80995
#
#                InvoiceDate  UnitPrice  CustomerID         Country        Date  \
# 61624  2011-01-18 10:17:00       1.04     12346.0  United Kingdom  2011-01-18
# 540422 2011-12-09 09:27:00       2.08     16446.0  United Kingdom  2011-12-09
#
#        MonthYear
# 61624    2011-01
# 540422   2011-12

# %%
df[df["Quantity"]>10000]
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 61619     541431     23166  MEDIUM CERAMIC TOP STORAGE JAR     74215
# 502122    578841     84826  ASSTD DESIGN 3D PAPER STICKERS     12540
# 540421    581483     23843     PAPER CRAFT , LITTLE BIRDIE     80995
#
#                InvoiceDate  UnitPrice  CustomerID         Country        Date  \
# 61619  2011-01-18 10:01:00       1.04     12346.0  United Kingdom  2011-01-18
# 502122 2011-11-25 15:57:00       0.00     13256.0  United Kingdom  2011-11-25
# 540421 2011-12-09 09:15:00       2.08     16446.0  United Kingdom  2011-12-09
#
#        MonthYear
# 61619    2011-01
# 502122   2011-11
# 540421   2011-12

# %%
df[df.duplicated()==True]
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 517       536409     21866        UNION JACK FLAG LUGGAGE TAG         1
# 527       536409     22866      HAND WARMER SCOTTY DOG DESIGN         1
# 537       536409     22900    SET 2 TEA TOWELS I LOVE LONDON          1
# 539       536409     22111       SCOTTIE DOG HOT WATER BOTTLE         1
# 555       536412     22327  ROUND SNACK BOXES SET OF 4 SKULLS         1
# ...          ...       ...                                ...       ...
# 541675    581538     22068        BLACK PIRATE TREASURE CHEST         1
# 541689    581538     23318     BOX OF 6 MINI VINTAGE CRACKERS         1
# 541692    581538     22992             REVOLVER WOODEN RULER          1
# 541699    581538     22694                       WICKER STAR          1
# 541701    581538     23343       JUMBO BAG VINTAGE CHRISTMAS          1
#
#                InvoiceDate  UnitPrice  CustomerID         Country        Date  \
# 517    2010-12-01 11:45:00       1.25     17908.0  United Kingdom  2010-12-01
# 527    2010-12-01 11:45:00       2.10     17908.0  United Kingdom  2010-12-01
# 537    2010-12-01 11:45:00       2.95     17908.0  United Kingdom  2010-12-01
# 539    2010-12-01 11:45:00       4.95     17908.0  United Kingdom  2010-12-01
# 555    2010-12-01 11:49:00       2.95     17920.0  United Kingdom  2010-12-01
# ...                    ...        ...         ...             ...         ...
# 541675 2011-12-09 11:34:00       0.39     14446.0  United Kingdom  2011-12-09
# 541689 2011-12-09 11:34:00       2.49     14446.0  United Kingdom  2011-12-09
# 541692 2011-12-09 11:34:00       1.95     14446.0  United Kingdom  2011-12-09
# 541699 2011-12-09 11:34:00       2.10     14446.0  United Kingdom  2011-12-09
# 541701 2011-12-09 11:34:00       2.08     14446.0  United Kingdom  2011-12-09
#
#        MonthYear
# 517      2010-12
# 527      2010-12
# 537      2010-12
# 539      2010-12
# 555      2010-12
# ...          ...
# 541675   2011-12
# 541689   2011-12
# 541692   2011-12
# 541699   2011-12
# 541701   2011-12
#
# [5268 rows x 10 columns]

# %%
pd.set_option('display.max_rows', df.shape[0]+1)
df[df["CustomerID"]==14397.0].sort_values("StockCode")
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 533102    581011     20846    ZINC HEART LATTICE T-LIGHT HOLDER        24
# 182822    552575     20846    ZINC HEART LATTICE T-LIGHT HOLDER        12
# 456313    575684     20846    ZINC HEART LATTICE T-LIGHT HOLDER        12
# 506162    579128     20846    ZINC HEART LATTICE T-LIGHT HOLDER        24
# 261713    559883     20846    ZINC HEART LATTICE T-LIGHT HOLDER        12
# 204452    554664     20846    ZINC HEART LATTICE T-LIGHT HOLDER        12
# 234473    557526     20846    ZINC HEART LATTICE T-LIGHT HOLDER        12
# 363318   C568559     20956   PORCELAIN T-LIGHT HOLDERS ASSORTED        -2
# 477581    577060     20956   PORCELAIN T-LIGHT HOLDERS ASSORTED        36
# 390317    570511     20956   PORCELAIN T-LIGHT HOLDERS ASSORTED        12
# 328600    565792     20956   PORCELAIN T-LIGHT HOLDERS ASSORTED        24
# 497261   C578355     20956   PORCELAIN T-LIGHT HOLDERS ASSORTED        -3
# 182827    552575     20975  12 PENCILS SMALL TUBE RED RETROSPOT        24
# 182828    552575     21294                 ETCHED GLASS COASTER        48
# 182830    552575     21742          LARGE ROUND WICKER PLATTER          2
# 182820    552575     22178      VICTORIAN GLASS HANGING T-LIGHT        24
# 308451    563982     22178      VICTORIAN GLASS HANGING T-LIGHT        48
# 424961    573294     22178      VICTORIAN GLASS HANGING T-LIGHT        36
# 398177    571225     22178      VICTORIAN GLASS HANGING T-LIGHT        42
# 390319    570511     22178      VICTORIAN GLASS HANGING T-LIGHT        36
# 540448   C581490     22178      VICTORIAN GLASS HANGING T-LIGHT       -12
# 291255    562442     22178      VICTORIAN GLASS HANGING T-LIGHT        36
# 276635    561067     22178      VICTORIAN GLASS HANGING T-LIGHT        36
# 497258   C578355     22178      VICTORIAN GLASS HANGING T-LIGHT        -3
# 477582    577060     22178      VICTORIAN GLASS HANGING T-LIGHT        24
# 234474    557526     22178      VICTORIAN GLASS HANGING T-LIGHT        36
# 223950    556496     22178      VICTORIAN GLASS HANGING T-LIGHT        36
# 204453    554664     22178      VICTORIAN GLASS HANGING T-LIGHT        24
# 506161    579128     22178      VICTORIAN GLASS HANGING T-LIGHT        48
# 522269    580394     22178      VICTORIAN GLASS HANGING T-LIGHT        48
# 533098    581011     22178      VICTORIAN GLASS HANGING T-LIGHT        48
# 456315    575684     22178      VICTORIAN GLASS HANGING T-LIGHT        30
# 328599    565792     22178      VICTORIAN GLASS HANGING T-LIGHT        36
# 477580    577060     22478             BIRDHOUSE GARDEN MARKER         20
# 398178    571225     22478             BIRDHOUSE GARDEN MARKER         10
# 522272    580394     22478             BIRDHOUSE GARDEN MARKER         20
# 533101    581011     22478             BIRDHOUSE GARDEN MARKER         20
# 390316    570511     22478             BIRDHOUSE GARDEN MARKER         10
# 328598    565792     22478             BIRDHOUSE GARDEN MARKER         10
# 261712    559883     22478             BIRDHOUSE GARDEN MARKER         10
# 328601    565792     22596  CHRISTMAS STAR WISH LIST CHALKBOARD        12
# 398180    571225     22596  CHRISTMAS STAR WISH LIST CHALKBOARD        12
# 497260   C578355     22596  CHRISTMAS STAR WISH LIST CHALKBOARD        -4
# 522273    580394     22596  CHRISTMAS STAR WISH LIST CHALKBOARD        12
# 456311    575684     22596  CHRISTMAS STAR WISH LIST CHALKBOARD        60
# 506159    579128     22600        CHRISTMAS RETROSPOT STAR WOOD        12
# 533103    581011     22600        CHRISTMAS RETROSPOT STAR WOOD        12
# 182829    552575     22615    PACK OF 12 CIRCUS PARADE TISSUES         24
# 506160    579128     22694                         WICKER STAR          6
# 182826    552575     22855                   FINE WICKER HEART         12
# 349803    567531     23130         MISTLETOE HEART WREATH GREEN         8
# 341324   C566752     23130         MISTLETOE HEART WREATH GREEN        -1
# 398179    571225     23130         MISTLETOE HEART WREATH GREEN         8
# 328602    565792     23130         MISTLETOE HEART WREATH GREEN         4
# 456314    575684     23130         MISTLETOE HEART WREATH GREEN         8
# 522271    580394     23144      ZINC T-LIGHT HOLDER STARS SMALL        12
# 456312    575684     23144      ZINC T-LIGHT HOLDER STARS SMALL       144
# 261711    559883     23144      ZINC T-LIGHT HOLDER STARS SMALL        12
# 182821    552575     23144      ZINC T-LIGHT HOLDER STARS SMALL        12
# 276636    561067     23144      ZINC T-LIGHT HOLDER STARS SMALL        12
# 533099    581011     23144      ZINC T-LIGHT HOLDER STARS SMALL        48
# 540449   C581490     23144      ZINC T-LIGHT HOLDER STARS SMALL       -11
# 424960    573294     23144      ZINC T-LIGHT HOLDER STARS SMALL        36
# 308454    563982     23144      ZINC T-LIGHT HOLDER STARS SMALL        12
# 398181    571225     23144      ZINC T-LIGHT HOLDER STARS SMALL        12
# 349804    567531     23144      ZINC T-LIGHT HOLDER STARS SMALL        24
# 328604    565792     23144      ZINC T-LIGHT HOLDER STARS SMALL        24
# 291258    562442     23144      ZINC T-LIGHT HOLDER STARS SMALL        12
# 182825    552575     23145       ZINC T-LIGHT HOLDER STAR LARGE        12
# 390320    570511     23145       ZINC T-LIGHT HOLDER STAR LARGE        12
# 533100    581011     23145       ZINC T-LIGHT HOLDER STAR LARGE        24
# 308453    563982     23145       ZINC T-LIGHT HOLDER STAR LARGE        12
# 291257    562442     23145       ZINC T-LIGHT HOLDER STAR LARGE        12
# 398182    571225     23145       ZINC T-LIGHT HOLDER STAR LARGE        12
# 424959    573294     23145       ZINC T-LIGHT HOLDER STAR LARGE        36
# 522268    580394     23145       ZINC T-LIGHT HOLDER STAR LARGE        36
# 261710    559883     37327        ASSTD MULTICOLOUR CIRCLES MUG        48
# 328603    565792     82484    WOOD BLACK BOARD ANT WHITE FINISH         2
# 390315    570511     82484    WOOD BLACK BOARD ANT WHITE FINISH         6
# 182823    552575     82484    WOOD BLACK BOARD ANT WHITE FINISH         2
# 204451    554664     82484    WOOD BLACK BOARD ANT WHITE FINISH         4
# 291256    562442     82484    WOOD BLACK BOARD ANT WHITE FINISH         4
# 308452    563982     82484    WOOD BLACK BOARD ANT WHITE FINISH         8
# 234475    557526     82484    WOOD BLACK BOARD ANT WHITE FINISH         4
# 398176    571225     82484    WOOD BLACK BOARD ANT WHITE FINISH         2
# 267552    560302     82484    WOOD BLACK BOARD ANT WHITE FINISH         6
# 390318    570511     84946         ANTIQUE SILVER T-LIGHT GLASS        24
# 522270    580394     84946         ANTIQUE SILVER T-LIGHT GLASS        24
# 308455    563982     84946         ANTIQUE SILVER T-LIGHT GLASS        24
# 182824    552575     84946         ANTIQUE SILVER T-LIGHT GLASS        12
# 497259   C578355     84946         ANTIQUE SILVER T-LIGHT GLASS        -2
# 477583    577060     84946         ANTIQUE SILVER T-LIGHT GLASS        12
# 456316    575684     84946         ANTIQUE SILVER T-LIGHT GLASS        12
# 506163    579128     84946         ANTIQUE SILVER T-LIGHT GLASS        12
# 276634    561067     84946         ANTIQUE SILVER T-LIGHT GLASS        36
#
#                InvoiceDate  UnitPrice  CustomerID         Country        Date  \
# 533102 2011-12-07 09:22:00       1.25     14397.0  United Kingdom  2011-12-07
# 182822 2011-05-10 12:25:00       1.25     14397.0  United Kingdom  2011-05-10
# 456313 2011-11-10 15:57:00       1.25     14397.0  United Kingdom  2011-11-10
# 506162 2011-11-28 12:30:00       1.25     14397.0  United Kingdom  2011-11-28
# 261713 2011-07-13 11:34:00       1.25     14397.0  United Kingdom  2011-07-13
# 204452 2011-05-25 14:40:00       1.25     14397.0  United Kingdom  2011-05-25
# 234473 2011-06-21 09:30:00       1.25     14397.0  United Kingdom  2011-06-21
# 363318 2011-09-27 16:37:00       1.25     14397.0  United Kingdom  2011-09-27
# 477581 2011-11-17 14:36:00       1.25     14397.0  United Kingdom  2011-11-17
# 390317 2011-10-11 10:24:00       1.25     14397.0  United Kingdom  2011-10-11
# 328600 2011-09-07 09:37:00       1.25     14397.0  United Kingdom  2011-09-07
# 497261 2011-11-24 10:13:00       1.25     14397.0  United Kingdom  2011-11-24
# 182827 2011-05-10 12:25:00       0.65     14397.0  United Kingdom  2011-05-10
# 182828 2011-05-10 12:25:00       0.39     14397.0  United Kingdom  2011-05-10
# 182830 2011-05-10 12:25:00       5.95     14397.0  United Kingdom  2011-05-10
# 182820 2011-05-10 12:25:00       1.25     14397.0  United Kingdom  2011-05-10
# 308451 2011-08-22 11:17:00       1.25     14397.0  United Kingdom  2011-08-22
# 424961 2011-10-28 15:32:00       1.95     14397.0  United Kingdom  2011-10-28
# 398177 2011-10-14 13:41:00       1.95     14397.0  United Kingdom  2011-10-14
# 390319 2011-10-11 10:24:00       1.95     14397.0  United Kingdom  2011-10-11
# 540448 2011-12-09 09:57:00       1.95     14397.0  United Kingdom  2011-12-09
# 291255 2011-08-04 18:31:00       1.25     14397.0  United Kingdom  2011-08-04
# 276635 2011-07-24 14:26:00       1.25     14397.0  United Kingdom  2011-07-24
# 497258 2011-11-24 10:13:00       1.95     14397.0  United Kingdom  2011-11-24
# 477582 2011-11-17 14:36:00       1.95     14397.0  United Kingdom  2011-11-17
# 234474 2011-06-21 09:30:00       1.25     14397.0  United Kingdom  2011-06-21
# 223950 2011-06-12 15:20:00       1.25     14397.0  United Kingdom  2011-06-12
# 204453 2011-05-25 14:40:00       1.25     14397.0  United Kingdom  2011-05-25
# 506161 2011-11-28 12:30:00       1.95     14397.0  United Kingdom  2011-11-28
# 522269 2011-12-04 10:53:00       1.95     14397.0  United Kingdom  2011-12-04
# 533098 2011-12-07 09:22:00       1.95     14397.0  United Kingdom  2011-12-07
# 456315 2011-11-10 15:57:00       1.95     14397.0  United Kingdom  2011-11-10
# 328599 2011-09-07 09:37:00       1.95     14397.0  United Kingdom  2011-09-07
# 477580 2011-11-17 14:36:00       1.25     14397.0  United Kingdom  2011-11-17
# 398178 2011-10-14 13:41:00       1.25     14397.0  United Kingdom  2011-10-14
# 522272 2011-12-04 10:53:00       1.25     14397.0  United Kingdom  2011-12-04
# 533101 2011-12-07 09:22:00       1.25     14397.0  United Kingdom  2011-12-07
# 390316 2011-10-11 10:24:00       1.25     14397.0  United Kingdom  2011-10-11
# 328598 2011-09-07 09:37:00       1.25     14397.0  United Kingdom  2011-09-07
# 261712 2011-07-13 11:34:00       1.25     14397.0  United Kingdom  2011-07-13
# 328601 2011-09-07 09:37:00       1.25     14397.0  United Kingdom  2011-09-07
# 398180 2011-10-14 13:41:00       1.25     14397.0  United Kingdom  2011-10-14
# 497260 2011-11-24 10:13:00       1.25     14397.0  United Kingdom  2011-11-24
# 522273 2011-12-04 10:53:00       1.25     14397.0  United Kingdom  2011-12-04
# 456311 2011-11-10 15:57:00       1.25     14397.0  United Kingdom  2011-11-10
# 506159 2011-11-28 12:30:00       0.85     14397.0  United Kingdom  2011-11-28
# 533103 2011-12-07 09:22:00       0.85     14397.0  United Kingdom  2011-12-07
# 182829 2011-05-10 12:25:00       0.29     14397.0  United Kingdom  2011-05-10
# 506160 2011-11-28 12:30:00       2.10     14397.0  United Kingdom  2011-11-28
# 182826 2011-05-10 12:25:00       1.25     14397.0  United Kingdom  2011-05-10
# 349803 2011-09-21 09:37:00       4.15     14397.0  United Kingdom  2011-09-21
# 341324 2011-09-14 15:46:00       4.15     14397.0  United Kingdom  2011-09-14
# 398179 2011-10-14 13:41:00       4.15     14397.0  United Kingdom  2011-10-14
# 328602 2011-09-07 09:37:00       4.15     14397.0  United Kingdom  2011-09-07
# 456314 2011-11-10 15:57:00       4.15     14397.0  United Kingdom  2011-11-10
# 522271 2011-12-04 10:53:00       0.83     14397.0  United Kingdom  2011-12-04
# 456312 2011-11-10 15:57:00       0.72     14397.0  United Kingdom  2011-11-10
# 261711 2011-07-13 11:34:00       0.83     14397.0  United Kingdom  2011-07-13
# 182821 2011-05-10 12:25:00       0.83     14397.0  United Kingdom  2011-05-10
# 276636 2011-07-24 14:26:00       0.83     14397.0  United Kingdom  2011-07-24
# 533099 2011-12-07 09:22:00       0.83     14397.0  United Kingdom  2011-12-07
# 540449 2011-12-09 09:57:00       0.83     14397.0  United Kingdom  2011-12-09
# 424960 2011-10-28 15:32:00       0.83     14397.0  United Kingdom  2011-10-28
# 308454 2011-08-22 11:17:00       0.83     14397.0  United Kingdom  2011-08-22
# 398181 2011-10-14 13:41:00       0.83     14397.0  United Kingdom  2011-10-14
# 349804 2011-09-21 09:37:00       0.83     14397.0  United Kingdom  2011-09-21
# 328604 2011-09-07 09:37:00       0.83     14397.0  United Kingdom  2011-09-07
# 291258 2011-08-04 18:31:00       0.83     14397.0  United Kingdom  2011-08-04
# 182825 2011-05-10 12:25:00       0.95     14397.0  United Kingdom  2011-05-10
# 390320 2011-10-11 10:24:00       0.95     14397.0  United Kingdom  2011-10-11
# 533100 2011-12-07 09:22:00       0.95     14397.0  United Kingdom  2011-12-07
# 308453 2011-08-22 11:17:00       0.95     14397.0  United Kingdom  2011-08-22
# 291257 2011-08-04 18:31:00       0.95     14397.0  United Kingdom  2011-08-04
# 398182 2011-10-14 13:41:00       0.95     14397.0  United Kingdom  2011-10-14
# 424959 2011-10-28 15:32:00       0.95     14397.0  United Kingdom  2011-10-28
# 522268 2011-12-04 10:53:00       0.95     14397.0  United Kingdom  2011-12-04
# 261710 2011-07-13 11:34:00       0.39     14397.0  United Kingdom  2011-07-13
# 328603 2011-09-07 09:37:00       7.95     14397.0  United Kingdom  2011-09-07
# 390315 2011-10-11 10:24:00       7.95     14397.0  United Kingdom  2011-10-11
# 182823 2011-05-10 12:25:00       7.95     14397.0  United Kingdom  2011-05-10
# 204451 2011-05-25 14:40:00       7.95     14397.0  United Kingdom  2011-05-25
# 291256 2011-08-04 18:31:00       7.95     14397.0  United Kingdom  2011-08-04
# 308452 2011-08-22 11:17:00       7.95     14397.0  United Kingdom  2011-08-22
# 234475 2011-06-21 09:30:00       7.95     14397.0  United Kingdom  2011-06-21
# 398176 2011-10-14 13:41:00       7.95     14397.0  United Kingdom  2011-10-14
# 267552 2011-07-18 10:43:00       7.95     14397.0  United Kingdom  2011-07-18
# 390318 2011-10-11 10:24:00       1.25     14397.0  United Kingdom  2011-10-11
# 522270 2011-12-04 10:53:00       1.25     14397.0  United Kingdom  2011-12-04
# 308455 2011-08-22 11:17:00       1.25     14397.0  United Kingdom  2011-08-22
# 182824 2011-05-10 12:25:00       1.25     14397.0  United Kingdom  2011-05-10
# 497259 2011-11-24 10:13:00       1.25     14397.0  United Kingdom  2011-11-24
# 477583 2011-11-17 14:36:00       1.25     14397.0  United Kingdom  2011-11-17
# 456316 2011-11-10 15:57:00       1.25     14397.0  United Kingdom  2011-11-10
# 506163 2011-11-28 12:30:00       1.25     14397.0  United Kingdom  2011-11-28
# 276634 2011-07-24 14:26:00       1.25     14397.0  United Kingdom  2011-07-24
#
#        MonthYear
# 533102   2011-12
# 182822   2011-05
# 456313   2011-11
# 506162   2011-11
# 261713   2011-07
# 204452   2011-05
# 234473   2011-06
# 363318   2011-09
# 477581   2011-11
# 390317   2011-10
# 328600   2011-09
# 497261   2011-11
# 182827   2011-05
# 182828   2011-05
# 182830   2011-05
# 182820   2011-05
# 308451   2011-08
# 424961   2011-10
# 398177   2011-10
# 390319   2011-10
# 540448   2011-12
# 291255   2011-08
# 276635   2011-07
# 497258   2011-11
# 477582   2011-11
# 234474   2011-06
# 223950   2011-06
# 204453   2011-05
# 506161   2011-11
# 522269   2011-12
# 533098   2011-12
# 456315   2011-11
# 328599   2011-09
# 477580   2011-11
# 398178   2011-10
# 522272   2011-12
# 533101   2011-12
# 390316   2011-10
# 328598   2011-09
# 261712   2011-07
# 328601   2011-09
# 398180   2011-10
# 497260   2011-11
# 522273   2011-12
# 456311   2011-11
# 506159   2011-11
# 533103   2011-12
# 182829   2011-05
# 506160   2011-11
# 182826   2011-05
# 349803   2011-09
# 341324   2011-09
# 398179   2011-10
# 328602   2011-09
# 456314   2011-11
# 522271   2011-12
# 456312   2011-11
# 261711   2011-07
# 182821   2011-05
# 276636   2011-07
# 533099   2011-12
# 540449   2011-12
# 424960   2011-10
# 308454   2011-08
# 398181   2011-10
# 349804   2011-09
# 328604   2011-09
# 291258   2011-08
# 182825   2011-05
# 390320   2011-10
# 533100   2011-12
# 308453   2011-08
# 291257   2011-08
# 398182   2011-10
# 424959   2011-10
# 522268   2011-12
# 261710   2011-07
# 328603   2011-09
# 390315   2011-10
# 182823   2011-05
# 204451   2011-05
# 291256   2011-08
# 308452   2011-08
# 234475   2011-06
# 398176   2011-10
# 267552   2011-07
# 390318   2011-10
# 522270   2011-12
# 308455   2011-08
# 182824   2011-05
# 497259   2011-11
# 477583   2011-11
# 456316   2011-11
# 506163   2011-11
# 276634   2011-07
